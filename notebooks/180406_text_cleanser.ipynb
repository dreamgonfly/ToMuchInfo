# %% [markdown]
# # 180406_text_cleanser

# %%
from konlpy.tag import Twitter
twitter = Twitter()

# %%
twitter.pos("왜그랬엌ㅋㅋㅋ", norm=True, stem=True)
# Out:
# [('왜', 'Noun'), ('그렇다', 'Adjective'), ('ㅋㅋ', 'KoreanParticle')]

# %%
raw_text = "아버지가 가방에 들어가신다. 왜그랬엌ㅋㅋㅋ"

# %%
' '.join([token for token, tag in twitter.pos(raw_text, norm=True)])
# Out:
# '아버지 가 가방 에 들어가신 다 . 왜 그랬 어 ㅋㅋ'

# %%
twitter.nouns("아버지가 가방에 들어가신다.")
# Out:
# ['아버지', '가방']

# %%
import re

# %%
import pandas as pd

# %%
with open("../data/movie.txt", 'r') as f:
    data = f.readlines()
    data = [line.strip() for line in data]
    data = pd.DataFrame(data, columns = ['comment'])

# %%
data
# Out:
#                                              comment
# 0                            아련한 향수를 떠올리게 만드는 추억의 영화
# 1                           SF 코미디 영화사에서 가장 주목해야할 영화
# 2                     mv00036133의 꿈이 고스란히 담겨진 최고의 영화
# 3                             전편을 120% 활용하는 천재적인 속편.
# 4                             1편만큼 재미있다. 3편만 조금 떨어짐.
# 5                            역시 전편을 능가하는 속편은 지극히 드물다
# 6                                     무슨 설명이 더 필요한가?
# 7                  mv00501003라는 이름만으로도 설레게 만드는 영화의 힘
# 8                             이때참 ac00000559가 멋져 보였지
# 9                                 시원하면서도 심장을 꽉 조여온다.
# 10                     mv00457204에 계속해줘도 계속보게 만드는 영화
# 11                     mv00457204에 만나는 mv00390115 캐빈
# 12                 mv00457204 시즌이면 항상 가장먼저 떠오르는 가족영화
# 13                '둘리'와 함께 언제고 mv00457201도 즐거운 '케빈'.
# 14                            E.T 같은 친구 한 명만 있었으면...
# 15                         영원한 스칼렛으로 기억 될 ac00939862
# 16                                록키 시리즈를 통틀어 최고!!!!
# 17                    전개와 결말이 보였던 영화. 그래도 감동 있었던 영화.
# 18                                 별도의 수식어가 필요없는 영화.
# 19                    "mv00000082 시리즈의 시작, 전설의 근원지점"
# 20      "오래된 영화ac00920758, 모든 mv00335020물의 아버지격인 영화"
# 21                                말이 필요없는 최고의 SF명작영화
# 22                 ac00001858 최고의 걸작은 <mv00000112>다!
# 23                          끔찍했지만 정말 재밌었다. 멋진 여전사 굿!
# 24                       자유를 향한 끝없는 집념은 없던 희망도 만들어낸다
# 25                     현실과 이상을 넘어선 참된 교육의 표본을 보여준 영화
# 26                              우리에겐 여전히 결핍된 참교육....
# 27                                  내 인생 최고의 영화 중 하나
# 28                             설명이 필요없다. mv00230755.
# 29                    너무 길다. 그래도 대작 서사시로서의 가치는 충분하다.
# ...                                              ...
# 520313                                           쩌러여
# 520314                      정말 잘만들었고 재밌었는데 너무 어려웠어ㅠㅠ
# 520315                             정말... 감독 대박~!!!!!
# 520316                    "여운이 가시지않는 영화, 정말 오랜만이네요!"
# 520317              mv00001962년 최고의 영화다. 다시보고 싶은 명작.
# 520318                             mv00300916....죽인다
# 520319                                      진짜대박....
# 520320             인간이 생각하는 모든 것을 ac01200883것 같다 강추~
# 520321                        2시간 40분이 14분처럼 느껴졌던 영화
# 520322                       기발은하다. 근데 그게 전부. 하품3번했네
# 520323                  마지막에 반전이랄까 진짜 인줄알았는데 토템이 안멈춤
# 520324                           그리 생각만큼 최고는 아닌데 볼만함
# 520325                정말 ac00343759퍼 놀런 감독에게 깜짝 놀랬다.
# 520326                진짜 오랜만에 관객을 가지고 노는 영화.. 미친천재감독
# 520327                        관객의 지적 도전욕구를 일깨우는 영화 ㅎ
# 520328                 화려하고스토리도좋은거같애용ㅋㅋㅋ돈하나도안아까워용강추!
# 520329                  마지막 부분 반전 여러가지 결말을 생각하게 된 영화
# 520330           기대만큼은 아니였다 ac01458291면만 놓쳐도 이해 못함..
# 520331                                        재미 없었음
# 520332                          굳! 스토리에 빠져들면 지루할틈이없다
# 520333          ac01161235보고도1점주는애들은못배운애들인가한심하다정말...
# 520334               mv00391777를 뛰어넘을줄은 몰랐다. 단연코 걸작.
# 520335                      재미있지만 9점ac01175227 아닌듯..
# 520336                                 굳 재밋다 .......
# 520337                전문가 평이 맞다.. 대작은 아니여 다크나이트에 비하면
# 520338                                         최고...
# 520339                   진짜 최고 ★ ★ ★ ★ ★ 감독은..대단하다..
# 520340                                   역시 놀런 형님이다!
# 520341                            정말 mv00221200가 완벽한
# 520342                     화장실을 못갔다...... 이런 영화 간만인듯
#
# [520343 rows x 1 columns]
