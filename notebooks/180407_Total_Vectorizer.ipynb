# %%
import pandas as pd
import numpy as np
import numpy as np
from collections import Counter
from konlpy.tag import Twitter
from gensim.models import FastText

# %%
class TotalVectorizer:
    """
    A dictionary that maps a word into a vector which 3 kinds of embedding concatenated
    [16] jamo based embedding
    [128] word based embedding
    [128] stemminized word based embedding
    [8] POS tags based embeddding
    """

    def __init__(self, tokenizer, config):
        self.tokenizer = Twitter()
        self.vocabulary_size = config.vocabulary_size
        self.embedding_size = 256
        self.PAD_TOKEN = '<PAD>'
        self.UNK_TOKEN = '<UNK>'
        self.fasttext = None

    def build_dictionary(self, data):
        self.vocab_words, self.word2idx, self.idx2word = self._build_vocabulary(data)
        self.embedding = self.load_vectors()
        print(self.embedding.shape)

    def indexer(self, word):
        try:
            return self.word2idx[word]
        except:
            return self.word2idx['<UNK>']

    def _build_vocabulary(self, data):
        reviews = [review for review, label in data]
        tokenized_reviews = [self.tokenizer.pos(review, norm=True) for review in reviews]

        tokens = [[token for token, pos in tokenized_list] for tokenized_list in tokenized_reviews]
        tags = [[pos for token, pos in tokenized_list] for tokenized_list in tokenized_reviews]

        self.fasttext = FastText(sentences=[' '.join(review) for review in tokens],
                                 size=self.embedding_size,
                                 max_vocab_size=self.vocabulary_size - 2)

        vocab_words = self.fasttext.wv.vocab
        word2idx = {word: idx for idx, word in enumerate(vocab_words)}
        word2idx['<UNK>'] = len(vocab_words)
        word2idx['<PAD>'] = len(vocab_words) + 1

        idx2word = {idx: word for idx, word in enumerate(vocab_words)}
        idx2word[len(vocab_words)] = '<UNK>'
        idx2word[len(vocab_words) + 1] = '<PAD>'

        return vocab_words, word2idx, idx2word

    def load_vectors(self):
        word_vectors = []
        for i in self.idx2word:
            word = self.idx2word[i]
            if word in ['<UNK>', '<PAD>']:
                vector = np.zeros(self.embedding_size)
            else:
                vector = self.fasttext.wv[word]
            word_vectors.append(vector)
        embedding = np.stack(word_vectors)
        return embedding

    def state_dict(self):
        state = {'idx2word': self.idx2word,
                 'word2idx': self.word2idx,
                 'vocab_words': self.vocab_words,
                 'embedding': self.embedding.tolist()}
        return state

    def load_state_dict(self, state_dict):
        self.idx2word = state_dict['idx2word']
        self.word2idx = state_dict['word2idx']
        self.vocab_words = state_dict['vocab_words']
        self.embedding = np.array(state_dict['embedding'])

# %%
twitter = Twitter()

# %%
with open("../code/data/small/train/train_data") as f:
    reviews = f.readlines()
    reviews = [line.strip() for line in reviews]
with open("../code/data/small/train/train_label") as f:
    labels = f.readlines()
    labels = [line.strip() for line in labels]

# %%
import re

# %%
maskings = re.compile("mv[0-9]*"||"ac[0-9]*")
# Out:
#   File "<ipython-input-35-b59cbc5a450a>", line 1
#     maskings = re.compile("mv[0-9]*"||"ac[0-9]*")
#                                      ^
# SyntaxError: invalid syntax

# %%
r.findall("mv10009가 최고야 ac1010이 들어가다니!")
# Out:
# ['mv10009']

# %%
def text_cleanser(raw_text):
    t = Twitter()
    t.pos()

# %%
cleaned_reviews =

# %%
reviews_tagged = [twitter.pos(review) for review in reviews]

# %%
reviews_tokens = [[token for token, pos in review] for review in reviews_tagged]

# %%
reviews_pos = [[pos for token, pos in review] for review in reviews_tagged]

# %%
fasttext_word = FastText()

# %%
fasttext_word.build_vocab(reviews_tokens)

# %%
fasttext_word.wv.vocab
# Out:
# {'아련한': <gensim.models.keyedvectors.Vocab at 0x1a38f465f8>,
#  '향수': <gensim.models.keyedvectors.Vocab at 0x1a38f46780>,
#  '를': <gensim.models.keyedvectors.Vocab at 0x1a38f46c18>,
#  '떠올리': <gensim.models.keyedvectors.Vocab at 0x1a38f46c50>,
#  '게': <gensim.models.keyedvectors.Vocab at 0x1a38f46160>,
#  '만드는': <gensim.models.keyedvectors.Vocab at 0x1a38f46978>,
#  '추억': <gensim.models.keyedvectors.Vocab at 0x1a38f46ef0>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x1a38f46320>,
#  '영화': <gensim.models.keyedvectors.Vocab at 0x1a38f46240>,
#  'SF': <gensim.models.keyedvectors.Vocab at 0x1a38f465c0>,
#  '코미디': <gensim.models.keyedvectors.Vocab at 0x1a38f467b8>,
#  '영화사': <gensim.models.keyedvectors.Vocab at 0x1a38f46eb8>,
#  '에서': <gensim.models.keyedvectors.Vocab at 0x1a38f46a20>,
#  '가장': <gensim.models.keyedvectors.Vocab at 0x1a38f46390>,
#  '해': <gensim.models.keyedvectors.Vocab at 0x1a38f46e48>,
#  '야할': <gensim.models.keyedvectors.Vocab at 0x1a38f46da0>,
#  'mv': <gensim.models.keyedvectors.Vocab at 0x1a38f46d30>,
#  '00036133': <gensim.models.keyedvectors.Vocab at 0x1a38f46f60>,
#  '꿈': <gensim.models.keyedvectors.Vocab at 0x1a38f46d68>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x1a38f46b38>,
#  '란': <gensim.models.keyedvectors.Vocab at 0x1a38f46f28>,
#  '히': <gensim.models.keyedvectors.Vocab at 0x1a38f46a58>,
#  '진': <gensim.models.keyedvectors.Vocab at 0x1a38f46e10>,
#  '최고': <gensim.models.keyedvectors.Vocab at 0x1a38f462e8>,
#  '전편': <gensim.models.keyedvectors.Vocab at 0x1a38f46208>,
#  '을': <gensim.models.keyedvectors.Vocab at 0x1a38f46908>,
#  '%': <gensim.models.keyedvectors.Vocab at 0x1a38f46198>,
#  '천재': <gensim.models.keyedvectors.Vocab at 0x1a38f469e8>,
#  '적': <gensim.models.keyedvectors.Vocab at 0x1a38f46278>,
#  '인': <gensim.models.keyedvectors.Vocab at 0x1a38f46128>,
#  '속편': <gensim.models.keyedvectors.Vocab at 0x1a38f461d0>,
#  '.': <gensim.models.keyedvectors.Vocab at 0x1a38f46b00>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x1a38f462b0>,
#  '편': <gensim.models.keyedvectors.Vocab at 0x1a38f46fd0>,
#  '만큼': <gensim.models.keyedvectors.Vocab at 0x1a38f46ac8>,
#  '재미있다': <gensim.models.keyedvectors.Vocab at 0x1a38f46518>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x1a38f46470>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x1a38f46cc0>,
#  '조금': <gensim.models.keyedvectors.Vocab at 0x1a38f46e80>,
#  '역시': <gensim.models.keyedvectors.Vocab at 0x1a38f466a0>,
#  '능가': <gensim.models.keyedvectors.Vocab at 0x1a38f464e0>,
#  '하는': <gensim.models.keyedvectors.Vocab at 0x1a38f46400>,
#  '은': <gensim.models.keyedvectors.Vocab at 0x1a36491198>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x1a36491860>,
#  '무슨': <gensim.models.keyedvectors.Vocab at 0x1a364918d0>,
#  '설명': <gensim.models.keyedvectors.Vocab at 0x1a36491550>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x1a390e1e10>,
#  '필요한': <gensim.models.keyedvectors.Vocab at 0x1a390e1668>,
#  '가': <gensim.models.keyedvectors.Vocab at 0x1a390e1b38>,
#  '?': <gensim.models.keyedvectors.Vocab at 0x1a390e1e48>,
#  '00501003': <gensim.models.keyedvectors.Vocab at 0x1a390e1cf8>,
#  '라는': <gensim.models.keyedvectors.Vocab at 0x1a390e1908>,
#  '이름': <gensim.models.keyedvectors.Vocab at 0x1a390e1cc0>,
#  '만으로도': <gensim.models.keyedvectors.Vocab at 0x1a390e1a58>,
#  '힘': <gensim.models.keyedvectors.Vocab at 0x1a390e1be0>,
#  '때': <gensim.models.keyedvectors.Vocab at 0x1a390e16a0>,
#  '참': <gensim.models.keyedvectors.Vocab at 0x1a390e1f28>,
#  'ac': <gensim.models.keyedvectors.Vocab at 0x1a390e17b8>,
#  '00000559': <gensim.models.keyedvectors.Vocab at 0x1a390e1a20>,
#  '멋져': <gensim.models.keyedvectors.Vocab at 0x1a390e1a90>,
#  '지': <gensim.models.keyedvectors.Vocab at 0x1a390e13c8>,
#  '면서도': <gensim.models.keyedvectors.Vocab at 0x1a390e1588>,
#  '심장': <gensim.models.keyedvectors.Vocab at 0x1a390e1d30>,
#  '온': <gensim.models.keyedvectors.Vocab at 0x1a390e1eb8>,
#  '00457204': <gensim.models.keyedvectors.Vocab at 0x1a390e17f0>,
#  '에': <gensim.models.keyedvectors.Vocab at 0x1a390e1c88>,
#  '계속': <gensim.models.keyedvectors.Vocab at 0x1a390e1ac8>,
#  '도': <gensim.models.keyedvectors.Vocab at 0x1a390e1fd0>,
#  '보게': <gensim.models.keyedvectors.Vocab at 0x1a390e15f8>,
#  '캐빈': <gensim.models.keyedvectors.Vocab at 0x1a390e1080>,
#  '이면': <gensim.models.keyedvectors.Vocab at 0x1a390e1860>,
#  '항상': <gensim.models.keyedvectors.Vocab at 0x1a390e1f60>,
#  '먼저': <gensim.models.keyedvectors.Vocab at 0x1a390e1c18>,
#  '가족영화': <gensim.models.keyedvectors.Vocab at 0x1a390e1748>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x1a390e1f98>,
#  '와': <gensim.models.keyedvectors.Vocab at 0x1a36489048>,
#  '함께': <gensim.models.keyedvectors.Vocab at 0x1a36489080>,
#  '언제': <gensim.models.keyedvectors.Vocab at 0x1a364890b8>,
#  '고': <gensim.models.keyedvectors.Vocab at 0x1a364890f0>,
#  '케빈': <gensim.models.keyedvectors.Vocab at 0x1a36489128>,
#  'T': <gensim.models.keyedvectors.Vocab at 0x1a36489160>,
#  '같은': <gensim.models.keyedvectors.Vocab at 0x1a36489198>,
#  '친구': <gensim.models.keyedvectors.Vocab at 0x1a364891d0>,
#  '한': <gensim.models.keyedvectors.Vocab at 0x1a36489208>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x1a36489240>,
#  '있었': <gensim.models.keyedvectors.Vocab at 0x1a36489278>,
#  '으면': <gensim.models.keyedvectors.Vocab at 0x1a364892b0>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x1a364892e8>,
#  '영원한': <gensim.models.keyedvectors.Vocab at 0x1a36489320>,
#  '스칼렛': <gensim.models.keyedvectors.Vocab at 0x1a36489358>,
#  '으로': <gensim.models.keyedvectors.Vocab at 0x1a36489390>,
#  '기억': <gensim.models.keyedvectors.Vocab at 0x1a364893c8>,
#  '될': <gensim.models.keyedvectors.Vocab at 0x1a36489400>,
#  '록키': <gensim.models.keyedvectors.Vocab at 0x1a36489438>,
#  '시리즈': <gensim.models.keyedvectors.Vocab at 0x1a36489470>,
#  '통틀어': <gensim.models.keyedvectors.Vocab at 0x1a364894a8>,
#  '!!!!': <gensim.models.keyedvectors.Vocab at 0x1a364894e0>,
#  '전개': <gensim.models.keyedvectors.Vocab at 0x1a36489518>,
#  '결말': <gensim.models.keyedvectors.Vocab at 0x1a36489550>,
#  '던': <gensim.models.keyedvectors.Vocab at 0x1a36489588>,
#  '그래도': <gensim.models.keyedvectors.Vocab at 0x1a364895c0>,
#  '감동': <gensim.models.keyedvectors.Vocab at 0x1a364895f8>,
#  '필요없': <gensim.models.keyedvectors.Vocab at 0x1a36489630>,
#  '는': <gensim.models.keyedvectors.Vocab at 0x1a36489668>,
#  '"': <gensim.models.keyedvectors.Vocab at 0x1a364896a0>,
#  '00000082': <gensim.models.keyedvectors.Vocab at 0x1a364896d8>,
#  '시작': <gensim.models.keyedvectors.Vocab at 0x1a36489710>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x1a36489748>,
#  '전설': <gensim.models.keyedvectors.Vocab at 0x1a36489780>,
#  '오래된': <gensim.models.keyedvectors.Vocab at 0x1a364897b8>,
#  '00920758': <gensim.models.keyedvectors.Vocab at 0x1a364897f0>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x1a36489828>,
#  '00335020': <gensim.models.keyedvectors.Vocab at 0x1a36489860>,
#  '물의': <gensim.models.keyedvectors.Vocab at 0x1a36489898>,
#  '아버지': <gensim.models.keyedvectors.Vocab at 0x1a364898d0>,
#  '말': <gensim.models.keyedvectors.Vocab at 0x1a36489908>,
#  '명작': <gensim.models.keyedvectors.Vocab at 0x1a36489940>,
#  '00001858': <gensim.models.keyedvectors.Vocab at 0x1a36489978>,
#  '걸작': <gensim.models.keyedvectors.Vocab at 0x1a364899b0>,
#  '<': <gensim.models.keyedvectors.Vocab at 0x1a364899e8>,
#  '>': <gensim.models.keyedvectors.Vocab at 0x1a36489a20>,
#  '!': <gensim.models.keyedvectors.Vocab at 0x1a36489a58>,
#  '지만': <gensim.models.keyedvectors.Vocab at 0x1a36489a90>,
#  '정말': <gensim.models.keyedvectors.Vocab at 0x1a36489ac8>,
#  '재밌었': <gensim.models.keyedvectors.Vocab at 0x1a36489b00>,
#  '멋진': <gensim.models.keyedvectors.Vocab at 0x1a36489b38>,
#  '여': <gensim.models.keyedvectors.Vocab at 0x1a36489b70>,
#  '굿': <gensim.models.keyedvectors.Vocab at 0x1a36489ba8>,
#  '자유': <gensim.models.keyedvectors.Vocab at 0x1a36489be0>,
#  '향한': <gensim.models.keyedvectors.Vocab at 0x1a36489c18>,
#  '끝없': <gensim.models.keyedvectors.Vocab at 0x1a36489c50>,
#  '희망': <gensim.models.keyedvectors.Vocab at 0x1a36489c88>,
#  '만들어': <gensim.models.keyedvectors.Vocab at 0x1a36489cc0>,
#  '낸': <gensim.models.keyedvectors.Vocab at 0x1a36489cf8>,
#  '현실': <gensim.models.keyedvectors.Vocab at 0x1a36489d30>,
#  '과': <gensim.models.keyedvectors.Vocab at 0x1a36489d68>,
#  '이상': <gensim.models.keyedvectors.Vocab at 0x1a36489da0>,
#  '넘어선': <gensim.models.keyedvectors.Vocab at 0x1a36489dd8>,
#  '참된': <gensim.models.keyedvectors.Vocab at 0x1a36489e10>,
#  '교육': <gensim.models.keyedvectors.Vocab at 0x1a36489e48>,
#  '보': <gensim.models.keyedvectors.Vocab at 0x1a36489e80>,
#  '여준': <gensim.models.keyedvectors.Vocab at 0x1a36489eb8>,
#  '우리': <gensim.models.keyedvectors.Vocab at 0x1a36489ef0>,
#  '에겐': <gensim.models.keyedvectors.Vocab at 0x1a36489f28>,
#  '여전히': <gensim.models.keyedvectors.Vocab at 0x1a36489f60>,
#  '된': <gensim.models.keyedvectors.Vocab at 0x1a36489f98>,
#  '....': <gensim.models.keyedvectors.Vocab at 0x1a36489fd0>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x1a36484048>,
#  '인생': <gensim.models.keyedvectors.Vocab at 0x1a36484080>,
#  '중': <gensim.models.keyedvectors.Vocab at 0x1a364840b8>,
#  '하나': <gensim.models.keyedvectors.Vocab at 0x1a364840f0>,
#  '00230755': <gensim.models.keyedvectors.Vocab at 0x1a36484128>,
#  '너무': <gensim.models.keyedvectors.Vocab at 0x1a36484160>,
#  '대작': <gensim.models.keyedvectors.Vocab at 0x1a36484198>,
#  '로서': <gensim.models.keyedvectors.Vocab at 0x1a364841d0>,
#  '가치': <gensim.models.keyedvectors.Vocab at 0x1a36484208>,
#  '충분하다': <gensim.models.keyedvectors.Vocab at 0x1a36484240>,
#  '외계인': <gensim.models.keyedvectors.Vocab at 0x1a36484278>,
#  '나오는': <gensim.models.keyedvectors.Vocab at 0x1a364842b0>,
#  '스러운': <gensim.models.keyedvectors.Vocab at 0x1a364842e8>,
#  '오락': <gensim.models.keyedvectors.Vocab at 0x1a36484320>,
#  '물': <gensim.models.keyedvectors.Vocab at 0x1a36484358>,
#  '클래식': <gensim.models.keyedvectors.Vocab at 0x1a36484390>,
#  '영원히': <gensim.models.keyedvectors.Vocab at 0x1a364843c8>,
#  '빛나는': <gensim.models.keyedvectors.Vocab at 0x1a36484400>,
#  '법': <gensim.models.keyedvectors.Vocab at 0x1a36484438>,
#  '남자': <gensim.models.keyedvectors.Vocab at 0x1a36484470>,
#  '들': <gensim.models.keyedvectors.Vocab at 0x1a364844a8>,
#  '위': <gensim.models.keyedvectors.Vocab at 0x1a364844e0>,
#  '00416725': <gensim.models.keyedvectors.Vocab at 0x1a36484518>,
#  '이야기': <gensim.models.keyedvectors.Vocab at 0x1a36484550>,
#  '가는': <gensim.models.keyedvectors.Vocab at 0x1a36484588>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x1a364845c0>,
#  '볼': <gensim.models.keyedvectors.Vocab at 0x1a364845f8>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x1a36484630>,
#  '있': <gensim.models.keyedvectors.Vocab at 0x1a36484668>,
#  '음': <gensim.models.keyedvectors.Vocab at 0x1a364846a0>,
#  '기대': <gensim.models.keyedvectors.Vocab at 0x1a364846d8>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x1a36484710>,
#  '오드리': <gensim.models.keyedvectors.Vocab at 0x1a36484748>,
#  '햅번': <gensim.models.keyedvectors.Vocab at 0x1a36484780>,
#  '00326143': <gensim.models.keyedvectors.Vocab at 0x1a364847b8>,
#  '전부': <gensim.models.keyedvectors.Vocab at 0x1a364847f0>,
#  '였': <gensim.models.keyedvectors.Vocab at 0x1a36484828>,
#  '왜': <gensim.models.keyedvectors.Vocab at 0x1a36484860>,
#  '종합': <gensim.models.keyedvectors.Vocab at 0x1a36484898>,
#  '예술': <gensim.models.keyedvectors.Vocab at 0x1a364848d0>,
#  '인가': <gensim.models.keyedvectors.Vocab at 0x1a36484908>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x1a36484940>,
#  '스릴': <gensim.models.keyedvectors.Vocab at 0x1a36484978>,
#  '음악': <gensim.models.keyedvectors.Vocab at 0x1a364849b0>,
#  '있는': <gensim.models.keyedvectors.Vocab at 0x1a364849e8>,
#  '토록': <gensim.models.keyedvectors.Vocab at 0x1a36484a20>,
#  '울': <gensim.models.keyedvectors.Vocab at 0x1a36484a58>,
#  '있다': <gensim.models.keyedvectors.Vocab at 0x1a36484a90>,
#  '니': <gensim.models.keyedvectors.Vocab at 0x1a36484ac8>,
#  '느와르': <gensim.models.keyedvectors.Vocab at 0x1a36484b00>,
#  '진수': <gensim.models.keyedvectors.Vocab at 0x1a36484b38>,
#  '누가': <gensim.models.keyedvectors.Vocab at 0x1a36484b70>,
#  '따라': <gensim.models.keyedvectors.Vocab at 0x1a36484ba8>,
#  '죠스': <gensim.models.keyedvectors.Vocab at 0x1a36484be0>,
#  '판': <gensim.models.keyedvectors.Vocab at 0x1a36484c18>,
#  '모험': <gensim.models.keyedvectors.Vocab at 0x1a36484c50>,
#  '이란': <gensim.models.keyedvectors.Vocab at 0x1a36484c88>,
#  '이런': <gensim.models.keyedvectors.Vocab at 0x1a36484cc0>,
#  '것': <gensim.models.keyedvectors.Vocab at 0x1a36484cf8>,
#  '요소': <gensim.models.keyedvectors.Vocab at 0x1a36484d30>,
#  '로': <gensim.models.keyedvectors.Vocab at 0x1a36484d68>,
#  '사랑': <gensim.models.keyedvectors.Vocab at 0x1a36484da0>,
#  '원조': <gensim.models.keyedvectors.Vocab at 0x1a36484dd8>,
#  'ㅋㅋ': <gensim.models.keyedvectors.Vocab at 0x1a36484e10>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x1a36484e48>,
#  '년': <gensim.models.keyedvectors.Vocab at 0x1a36484e80>,
#  '지난': <gensim.models.keyedvectors.Vocab at 0x1a36484eb8>,
#  '지금': <gensim.models.keyedvectors.Vocab at 0x1a36484ef0>,
#  '손': <gensim.models.keyedvectors.Vocab at 0x1a36484f28>,
#  '쥐': <gensim.models.keyedvectors.Vocab at 0x1a36484f60>,
#  '아직': <gensim.models.keyedvectors.Vocab at 0x1a36484f98>,
#  '이만': <gensim.models.keyedvectors.Vocab at 0x1a36484fd0>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x1a36481048>,
#  '했': <gensim.models.keyedvectors.Vocab at 0x1a36481080>,
#  '보다': <gensim.models.keyedvectors.Vocab at 0x1a364810b8>,
#  '나은': <gensim.models.keyedvectors.Vocab at 0x1a364810f0>,
#  '레전드': <gensim.models.keyedvectors.Vocab at 0x1a36481128>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x1a36481160>,
#  '자체': <gensim.models.keyedvectors.Vocab at 0x1a36481198>,
#  '히치콕': <gensim.models.keyedvectors.Vocab at 0x1a364811d0>,
#  '상업': <gensim.models.keyedvectors.Vocab at 0x1a36481208>,
#  '성찰': <gensim.models.keyedvectors.Vocab at 0x1a36481240>,
#  '용기': <gensim.models.keyedvectors.Vocab at 0x1a36481278>,
#  '돋보이는': <gensim.models.keyedvectors.Vocab at 0x1a364812b0>,
#  '작품': <gensim.models.keyedvectors.Vocab at 0x1a364812e8>,
#  '놀랍': <gensim.models.keyedvectors.Vocab at 0x1a36481320>,
#  '웃음': <gensim.models.keyedvectors.Vocab at 0x1a36481358>,
#  '(': <gensim.models.keyedvectors.Vocab at 0x1a36481390>,
#  ')': <gensim.models.keyedvectors.Vocab at 0x1a364813c8>,
#  '아직까지': <gensim.models.keyedvectors.Vocab at 0x1a36481400>,
#  '이라도': <gensim.models.keyedvectors.Vocab at 0x1a36481438>,
#  '라': <gensim.models.keyedvectors.Vocab at 0x1a36481470>,
#  '눈': <gensim.models.keyedvectors.Vocab at 0x1a364814a8>,
#  '않았': <gensim.models.keyedvectors.Vocab at 0x1a364814e0>,
#  '고전': <gensim.models.keyedvectors.Vocab at 0x1a36481518>,
#  '보여': <gensim.models.keyedvectors.Vocab at 0x1a36481550>,
#  '주': <gensim.models.keyedvectors.Vocab at 0x1a36481588>,
#  '마지막': <gensim.models.keyedvectors.Vocab at 0x1a364815c0>,
#  '장면': <gensim.models.keyedvectors.Vocab at 0x1a364815f8>,
#  '함': <gensim.models.keyedvectors.Vocab at 0x1a36481630>,
#  '느끼': <gensim.models.keyedvectors.Vocab at 0x1a36481668>,
#  '스필버그': <gensim.models.keyedvectors.Vocab at 0x1a364816a0>,
#  '뛰어난': <gensim.models.keyedvectors.Vocab at 0x1a364816d8>,
#  '연출': <gensim.models.keyedvectors.Vocab at 0x1a36481710>,
#  '여운': <gensim.models.keyedvectors.Vocab at 0x1a36481748>,
#  '남긴': <gensim.models.keyedvectors.Vocab at 0x1a36481780>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x1a364817b8>,
#  '캐릭터': <gensim.models.keyedvectors.Vocab at 0x1a364817f0>,
#  '주의': <gensim.models.keyedvectors.Vocab at 0x1a36481828>,
#  '00887011': <gensim.models.keyedvectors.Vocab at 0x1a36481860>,
#  '질': <gensim.models.keyedvectors.Vocab at 0x1a36481898>,
#  '않는': <gensim.models.keyedvectors.Vocab at 0x1a364818d0>,
#  '어릴': <gensim.models.keyedvectors.Vocab at 0x1a36481908>,
#  '극장': <gensim.models.keyedvectors.Vocab at 0x1a36481940>,
#  '봤': <gensim.models.keyedvectors.Vocab at 0x1a36481978>,
#  '재미있었': <gensim.models.keyedvectors.Vocab at 0x1a364819b0>,
#  '있게': <gensim.models.keyedvectors.Vocab at 0x1a364819e8>,
#  '해준': <gensim.models.keyedvectors.Vocab at 0x1a36481a20>,
#  '인류': <gensim.models.keyedvectors.Vocab at 0x1a36481a58>,
#  '역사상': <gensim.models.keyedvectors.Vocab at 0x1a36481a90>,
#  '위대한': <gensim.models.keyedvectors.Vocab at 0x1a36481ac8>,
#  '어른': <gensim.models.keyedvectors.Vocab at 0x1a36481b00>,
#  '마음': <gensim.models.keyedvectors.Vocab at 0x1a36481b38>,
#  '허무': <gensim.models.keyedvectors.Vocab at 0x1a36481b70>,
#  '존재': <gensim.models.keyedvectors.Vocab at 0x1a36481ba8>,
#  '끝': <gensim.models.keyedvectors.Vocab at 0x1a36481be0>,
#  '아니': <gensim.models.keyedvectors.Vocab at 0x1a36481c18>,
#  '01266023': <gensim.models.keyedvectors.Vocab at 0x1a36481c50>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x1a36481c88>,
#  '몰입': <gensim.models.keyedvectors.Vocab at 0x1a36481cc0>,
#  '해서': <gensim.models.keyedvectors.Vocab at 0x1a36481cf8>,
#  '너무나': <gensim.models.keyedvectors.Vocab at 0x1a36481d30>,
#  '수작': <gensim.models.keyedvectors.Vocab at 0x1a36481d68>,
#  '보고': <gensim.models.keyedvectors.Vocab at 0x1a36481da0>,
#  '스타일': <gensim.models.keyedvectors.Vocab at 0x1a36481dd8>,
#  '할': <gensim.models.keyedvectors.Vocab at 0x1a36481e10>,
#  '없다': <gensim.models.keyedvectors.Vocab at 0x1a36481e48>,
#  '뎁': <gensim.models.keyedvectors.Vocab at 0x1a36481e80>,
#  '인상': <gensim.models.keyedvectors.Vocab at 0x1a36481eb8>,
#  '어떤': <gensim.models.keyedvectors.Vocab at 0x1a36481ef0>,
#  '에서의': <gensim.models.keyedvectors.Vocab at 0x1a36481f28>,
#  '드': <gensim.models.keyedvectors.Vocab at 0x1a36481f60>,
#  '표정': <gensim.models.keyedvectors.Vocab at 0x1a36481f98>,
#  '잊': <gensim.models.keyedvectors.Vocab at 0x1a36481fd0>,
#  '단순한': <gensim.models.keyedvectors.Vocab at 0x1a3648f048>,
#  'B': <gensim.models.keyedvectors.Vocab at 0x1a3648f080>,
#  '무비': <gensim.models.keyedvectors.Vocab at 0x1a3648f0b8>,
#  '철학': <gensim.models.keyedvectors.Vocab at 0x1a3648f0f0>,
#  '느껴': <gensim.models.keyedvectors.Vocab at 0x1a3648f128>,
#  '보자': <gensim.models.keyedvectors.Vocab at 0x1a3648f160>,
#  '액션': <gensim.models.keyedvectors.Vocab at 0x1a3648f198>,
#  '멜로': <gensim.models.keyedvectors.Vocab at 0x1a3648f1d0>,
#  '사회': <gensim.models.keyedvectors.Vocab at 0x1a3648f208>,
#  '00217576': <gensim.models.keyedvectors.Vocab at 0x1a3648f240>,
#  '재밌': <gensim.models.keyedvectors.Vocab at 0x1a3648f278>,
#  '00477430': <gensim.models.keyedvectors.Vocab at 0x1a3648f2b0>,
#  '그렇게': <gensim.models.keyedvectors.Vocab at 0x1a3648f2e8>,
#  '나쁘': <gensim.models.keyedvectors.Vocab at 0x1a3648f320>,
#  '지도': <gensim.models.keyedvectors.Vocab at 0x1a3648f358>,
#  '소설': <gensim.models.keyedvectors.Vocab at 0x1a3648f390>,
#  '모두': <gensim.models.keyedvectors.Vocab at 0x1a3648f3c8>,
#  '왔': <gensim.models.keyedvectors.Vocab at 0x1a3648f400>,
#  '00355558': <gensim.models.keyedvectors.Vocab at 0x1a3648f438>,
#  'OST': <gensim.models.keyedvectors.Vocab at 0x1a3648f470>,
#  '잊혀지': <gensim.models.keyedvectors.Vocab at 0x1a3648f4a8>,
#  '삶': <gensim.models.keyedvectors.Vocab at 0x1a3648f4e0>,
#  '힘들': <gensim.models.keyedvectors.Vocab at 0x1a3648f518>,
#  '보면': <gensim.models.keyedvectors.Vocab at 0x1a3648f550>,
#  '큰': <gensim.models.keyedvectors.Vocab at 0x1a3648f588>,
#  '교훈': <gensim.models.keyedvectors.Vocab at 0x1a3648f5c0>,
#  '감히': <gensim.models.keyedvectors.Vocab at 0x1a3648f5f8>,
#  '없었': <gensim.models.keyedvectors.Vocab at 0x1a3648f630>,
#  '흥미': <gensim.models.keyedvectors.Vocab at 0x1a3648f668>,
#  '편의': <gensim.models.keyedvectors.Vocab at 0x1a3648f6a0>,
#  '마무리': <gensim.models.keyedvectors.Vocab at 0x1a3648f6d8>,
#  '하다': <gensim.models.keyedvectors.Vocab at 0x1a3648f710>,
#  '세기': <gensim.models.keyedvectors.Vocab at 0x1a3648f748>,
#  '그럭저럭': <gensim.models.keyedvectors.Vocab at 0x1a3648f780>,
#  '보는': <gensim.models.keyedvectors.Vocab at 0x1a3648f7b8>,
#  '흥미로운': <gensim.models.keyedvectors.Vocab at 0x1a3648f7f0>,
#  '00247312': <gensim.models.keyedvectors.Vocab at 0x1a3648f828>,
#  '시각': <gensim.models.keyedvectors.Vocab at 0x1a3648f860>,
#  '충격': <gensim.models.keyedvectors.Vocab at 0x1a3648f898>,
#  '외': <gensim.models.keyedvectors.Vocab at 0x1a3648f8d0>,
#  '에도': <gensim.models.keyedvectors.Vocab at 0x1a3648f908>,
#  '장점': <gensim.models.keyedvectors.Vocab at 0x1a3648f940>,
#  '충분히': <gensim.models.keyedvectors.Vocab at 0x1a3648f978>,
#  '많은': <gensim.models.keyedvectors.Vocab at 0x1a3648f9b0>,
#  '요즘': <gensim.models.keyedvectors.Vocab at 0x1a3648f9e8>,
#  '공포영화': <gensim.models.keyedvectors.Vocab at 0x1a3648fa20>,
#  '와는': <gensim.models.keyedvectors.Vocab at 0x1a3648fa58>,
#  '맨': <gensim.models.keyedvectors.Vocab at 0x1a3648fa90>,
#  '그리고': <gensim.models.keyedvectors.Vocab at 0x1a3648fac8>,
#  '놀라운': <gensim.models.keyedvectors.Vocab at 0x1a3648fb00>,
#  '호러': <gensim.models.keyedvectors.Vocab at 0x1a3648fb38>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x1a3648fb70>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x1a3648fba8>,
#  '00165583': <gensim.models.keyedvectors.Vocab at 0x1a3648fbe0>,
#  '."': <gensim.models.keyedvectors.Vocab at 0x1a3648fc18>,
#  '운': <gensim.models.keyedvectors.Vocab at 0x1a3648fc50>,
#  '거장': <gensim.models.keyedvectors.Vocab at 0x1a3648fc88>,
#  '에게': <gensim.models.keyedvectors.Vocab at 0x1a3648fcc0>,
#  '가능한': <gensim.models.keyedvectors.Vocab at 0x1a3648fcf8>,
#  '휴머니즘': <gensim.models.keyedvectors.Vocab at 0x1a3648fd30>,
#  '아': <gensim.models.keyedvectors.Vocab at 0x1a3648fd68>,
#  '남': <gensim.models.keyedvectors.Vocab at 0x1a3648fda0>,
#  '좋': <gensim.models.keyedvectors.Vocab at 0x1a3648fdd8>,
#  '역사': <gensim.models.keyedvectors.Vocab at 0x1a3648fe10>,
#  '소재': <gensim.models.keyedvectors.Vocab at 0x1a3648fe48>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x1a3648fe80>,
#  '그런데': <gensim.models.keyedvectors.Vocab at 0x1a3648feb8>,
#  '???': <gensim.models.keyedvectors.Vocab at 0x1a3648fef0>,
#  '느껴졌': <gensim.models.keyedvectors.Vocab at 0x1a3648ff28>,
#  '매우': <gensim.models.keyedvectors.Vocab at 0x1a3648ff60>,
#  '01312395': <gensim.models.keyedvectors.Vocab at 0x1a3648ff98>,
#  '모습': <gensim.models.keyedvectors.Vocab at 0x1a3648ffd0>,
#  '00069433': <gensim.models.keyedvectors.Vocab at 0x1a3920b048>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x1a3920b080>,
#  '현재': <gensim.models.keyedvectors.Vocab at 0x1a3920b0b8>,
#  '슬프': <gensim.models.keyedvectors.Vocab at 0x1a3920b0f0>,
#  '왕': <gensim.models.keyedvectors.Vocab at 0x1a3920b128>,
#  '귀환': <gensim.models.keyedvectors.Vocab at 0x1a3920b160>,
#  '앞': <gensim.models.keyedvectors.Vocab at 0x1a3920b198>,
#  '애': <gensim.models.keyedvectors.Vocab at 0x1a3920b1d0>,
#  'D': <gensim.models.keyedvectors.Vocab at 0x1a3920b208>,
#  '두': <gensim.models.keyedvectors.Vocab at 0x1a3920b240>,
#  '웅장': <gensim.models.keyedvectors.Vocab at 0x1a3920b278>,
#  '비': <gensim.models.keyedvectors.Vocab at 0x1a3920b2b0>,
#  '디즈니': <gensim.models.keyedvectors.Vocab at 0x1a3920b2e8>,
#  '애니메이션': <gensim.models.keyedvectors.Vocab at 0x1a3920b320>,
#  '안된': <gensim.models.keyedvectors.Vocab at 0x1a3920b358>,
#  '이건': <gensim.models.keyedvectors.Vocab at 0x1a3920b390>,
#  '최고다': <gensim.models.keyedvectors.Vocab at 0x1a3920b3c8>,
#  '독특한': <gensim.models.keyedvectors.Vocab at 0x1a3920b400>,
#  '구성': <gensim.models.keyedvectors.Vocab at 0x1a3920b438>,
#  '됐': <gensim.models.keyedvectors.Vocab at 0x1a3920b470>,
#  '스승': <gensim.models.keyedvectors.Vocab at 0x1a3920b4a8>,
#  '이자': <gensim.models.keyedvectors.Vocab at 0x1a3920b4e0>,
#  '형님': <gensim.models.keyedvectors.Vocab at 0x1a3920b518>,
#  '이다': <gensim.models.keyedvectors.Vocab at 0x1a3920b550>,
#  '연기': <gensim.models.keyedvectors.Vocab at 0x1a3920b588>,
#  '빛': <gensim.models.keyedvectors.Vocab at 0x1a3920b5c0>,
#  '발': <gensim.models.keyedvectors.Vocab at 0x1a3920b5f8>,
#  '하던': <gensim.models.keyedvectors.Vocab at 0x1a3920b630>,
#  '식': <gensim.models.keyedvectors.Vocab at 0x1a3920b668>,
#  '결정': <gensim.models.keyedvectors.Vocab at 0x1a3920b6a0>,
#  '체': <gensim.models.keyedvectors.Vocab at 0x1a3920b6d8>,
#  '로맨틱': <gensim.models.keyedvectors.Vocab at 0x1a3920b710>,
#  '코메디': <gensim.models.keyedvectors.Vocab at 0x1a3920b748>,
#  '쓰': <gensim.models.keyedvectors.Vocab at 0x1a3920b780>,
#  '기에': <gensim.models.keyedvectors.Vocab at 0x1a3920b7b8>,
#  '픽사': <gensim.models.keyedvectors.Vocab at 0x1a3920b7f0>,
#  '하고': <gensim.models.keyedvectors.Vocab at 0x1a3920b828>,
#  '넘치는': <gensim.models.keyedvectors.Vocab at 0x1a3920b860>,
#  '애니': <gensim.models.keyedvectors.Vocab at 0x1a3920b898>,
#  '다운': <gensim.models.keyedvectors.Vocab at 0x1a3920b8d0>,
#  '.."': <gensim.models.keyedvectors.Vocab at 0x1a3920b908>,
#  '전형': <gensim.models.keyedvectors.Vocab at 0x1a3920b940>,
#  '미국': <gensim.models.keyedvectors.Vocab at 0x1a3920b978>,
#  '드라마': <gensim.models.keyedvectors.Vocab at 0x1a3920b9b0>,
#  '난': <gensim.models.keyedvectors.Vocab at 0x1a3920b9e8>,
#  '한마디': <gensim.models.keyedvectors.Vocab at 0x1a3920ba20>,
#  '그러나': <gensim.models.keyedvectors.Vocab at 0x1a3920ba58>,
#  '까지': <gensim.models.keyedvectors.Vocab at 0x1a3920ba90>,
#  '지는': <gensim.models.keyedvectors.Vocab at 0x1a3920bac8>,
#  '잘': <gensim.models.keyedvectors.Vocab at 0x1a3920bb00>,
#  '모르': <gensim.models.keyedvectors.Vocab at 0x1a3920bb38>,
#  '겠': <gensim.models.keyedvectors.Vocab at 0x1a3920bb70>,
#  '생애': <gensim.models.keyedvectors.Vocab at 0x1a3920bba8>,
#  '베스트': <gensim.models.keyedvectors.Vocab at 0x1a3920bbe0>,
#  '한편': <gensim.models.keyedvectors.Vocab at 0x1a3920bc18>,
#  '터': <gensim.models.keyedvectors.Vocab at 0x1a3920bc50>,
#  '조화': <gensim.models.keyedvectors.Vocab at 0x1a3920bc88>,
#  'TV': <gensim.models.keyedvectors.Vocab at 0x1a3920bcc0>,
#  '말로': <gensim.models.keyedvectors.Vocab at 0x1a3920bcf8>,
#  '무엇': <gensim.models.keyedvectors.Vocab at 0x1a3920bd30>,
#  '오': <gensim.models.keyedvectors.Vocab at 0x1a3920bd68>,
#  '.....': <gensim.models.keyedvectors.Vocab at 0x1a3920bda0>,
#  '원작': <gensim.models.keyedvectors.Vocab at 0x1a3920bdd8>,
#  '만들어진': <gensim.models.keyedvectors.Vocab at 0x1a3920be10>,
#  '추천': <gensim.models.keyedvectors.Vocab at 0x1a3920be48>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x1a3920be80>,
#  '점도': <gensim.models.keyedvectors.Vocab at 0x1a3920beb8>,
#  '모': <gensim.models.keyedvectors.Vocab at 0x1a3920bef0>,
#  '점수': <gensim.models.keyedvectors.Vocab at 0x1a3920bf28>,
#  '주고': <gensim.models.keyedvectors.Vocab at 0x1a3920bf60>,
#  '싶다': <gensim.models.keyedvectors.Vocab at 0x1a3920bf98>,
#  '무난': <gensim.models.keyedvectors.Vocab at 0x1a3920bfd0>,
#  '완전': <gensim.models.keyedvectors.Vocab at 0x1a3920f1d0>,
#  '재밌고': <gensim.models.keyedvectors.Vocab at 0x1a3920f0b8>,
#  '판타지': <gensim.models.keyedvectors.Vocab at 0x1a3920f5f8>,
#  '출연': <gensim.models.keyedvectors.Vocab at 0x1a3920f048>,
#  '관객': <gensim.models.keyedvectors.Vocab at 0x1a3920f198>,
#  '실망': <gensim.models.keyedvectors.Vocab at 0x1a3920f208>,
#  '시키': <gensim.models.keyedvectors.Vocab at 0x1a3920f2b0>,
#  '깊게': <gensim.models.keyedvectors.Vocab at 0x1a3920f358>,
#  '만든': <gensim.models.keyedvectors.Vocab at 0x1a3920f3c8>,
#  '청소년': <gensim.models.keyedvectors.Vocab at 0x1a3920f400>,
#  '아이': <gensim.models.keyedvectors.Vocab at 0x1a3920f470>,
#  '꼭': <gensim.models.keyedvectors.Vocab at 0x1a3920f4a8>,
#  '~': <gensim.models.keyedvectors.Vocab at 0x1a3920f518>,
#  '처음': <gensim.models.keyedvectors.Vocab at 0x1a3920f550>,
#  '동생': <gensim.models.keyedvectors.Vocab at 0x1a3920f588>,
#  '씩': <gensim.models.keyedvectors.Vocab at 0x1a3920f240>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x1a3920f0f0>,
#  '며': <gensim.models.keyedvectors.Vocab at 0x1a3920f160>,
#  '보았': <gensim.models.keyedvectors.Vocab at 0x1a3920f710>,
#  '슬픈': <gensim.models.keyedvectors.Vocab at 0x1a3920f6d8>,
#  '매력': <gensim.models.keyedvectors.Vocab at 0x1a3920f080>,
#  '이지': <gensim.models.keyedvectors.Vocab at 0x1a3920f4e0>,
#  '않은': <gensim.models.keyedvectors.Vocab at 0x1a3920f630>,
#  '실화': <gensim.models.keyedvectors.Vocab at 0x1a3920f7b8>,
#  '스토리': <gensim.models.keyedvectors.Vocab at 0x1a3920f860>,
#  '언제나': <gensim.models.keyedvectors.Vocab at 0x1a3920f908>,
#  '인간': <gensim.models.keyedvectors.Vocab at 0x1a3920f9b0>,
#  '준': <gensim.models.keyedvectors.Vocab at 0x1a3920fb00>,
#  '만하': <gensim.models.keyedvectors.Vocab at 0x1a3920f6a0>,
#  '즐길': <gensim.models.keyedvectors.Vocab at 0x1a3920f2e8>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x1a3920f5c0>,
#  '재밌다': <gensim.models.keyedvectors.Vocab at 0x1a3920f748>,
#  '그거': <gensim.models.keyedvectors.Vocab at 0x1a3920f438>,
#  '받은': <gensim.models.keyedvectors.Vocab at 0x1a3920f320>,
#  '여자': <gensim.models.keyedvectors.Vocab at 0x1a3920f278>,
#  '신': <gensim.models.keyedvectors.Vocab at 0x1a3920f780>,
#  '력': <gensim.models.keyedvectors.Vocab at 0x1a3920f898>,
#  '코믹': <gensim.models.keyedvectors.Vocab at 0x1a3920f9e8>,
#  '호러영화': <gensim.models.keyedvectors.Vocab at 0x1a3920fa58>,
#  '긴장감': <gensim.models.keyedvectors.Vocab at 0x1a3920f390>,
#  '심리': <gensim.models.keyedvectors.Vocab at 0x1a3920f940>,
#  '저': <gensim.models.keyedvectors.Vocab at 0x1a3920f128>,
#  '예산': <gensim.models.keyedvectors.Vocab at 0x1a3920fa90>,
#  '으로도': <gensim.models.keyedvectors.Vocab at 0x1a3920fac8>,
#  '만들': <gensim.models.keyedvectors.Vocab at 0x1a3920f668>,
#  '스럽': <gensim.models.keyedvectors.Vocab at 0x1a3920f978>,
#  '헐리웃': <gensim.models.keyedvectors.Vocab at 0x1a3920f828>,
#  '에만': <gensim.models.keyedvectors.Vocab at 0x1a3920fa20>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x1a3920fe80>,
#  '까': <gensim.models.keyedvectors.Vocab at 0x1a3920fba8>,
#  '시대': <gensim.models.keyedvectors.Vocab at 0x1a3920fbe0>,
#  '비극': <gensim.models.keyedvectors.Vocab at 0x1a3920fc50>,
#  '유쾌': <gensim.models.keyedvectors.Vocab at 0x1a3920fcc0>,
#  '귀여운': <gensim.models.keyedvectors.Vocab at 0x1a3920fcf8>,
#  '토토': <gensim.models.keyedvectors.Vocab at 0x1a3920fd68>,
#  '멋지': <gensim.models.keyedvectors.Vocab at 0x1a3920fda0>,
#  '생각하게': <gensim.models.keyedvectors.Vocab at 0x1a3920fe10>,
#  '꽤': <gensim.models.keyedvectors.Vocab at 0x1a3920fe48>,
#  '오래': <gensim.models.keyedvectors.Vocab at 0x1a3920feb8>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x1a3920fef0>,
#  '로맨스': <gensim.models.keyedvectors.Vocab at 0x1a3920ff60>,
#  '얼마나': <gensim.models.keyedvectors.Vocab at 0x1a3920fdd8>,
#  '서': <gensim.models.keyedvectors.Vocab at 0x1a3920fc18>,
#  '눈물': <gensim.models.keyedvectors.Vocab at 0x1a3920fd30>,
#  '요': <gensim.models.keyedvectors.Vocab at 0x1a3920f7f0>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x1a3920ff98>,
#  '이렇게': <gensim.models.keyedvectors.Vocab at 0x1a3920f8d0>,
#  '빨리': <gensim.models.keyedvectors.Vocab at 0x1a3920ff28>,
#  '갈': <gensim.models.keyedvectors.Vocab at 0x1a3920ffd0>,
#  '줄': <gensim.models.keyedvectors.Vocab at 0x1a3920fb70>,
#  '이야': <gensim.models.keyedvectors.Vocab at 0x1a3920fc88>,
#  '사랑하는': <gensim.models.keyedvectors.Vocab at 0x1a3920fb38>,
#  '위한': <gensim.models.keyedvectors.Vocab at 0x1a39211048>,
#  '전쟁': <gensim.models.keyedvectors.Vocab at 0x1a392110b8>,
#  '화려한': <gensim.models.keyedvectors.Vocab at 0x1a39211128>,
#  '화끈': <gensim.models.keyedvectors.Vocab at 0x1a39211240>,
#  '멋있는': <gensim.models.keyedvectors.Vocab at 0x1a392112e8>,
#  '차이': <gensim.models.keyedvectors.Vocab at 0x1a39211358>,
#  '노력': <gensim.models.keyedvectors.Vocab at 0x1a39211390>,
#  '차': <gensim.models.keyedvectors.Vocab at 0x1a39211400>,
#  '분': <gensim.models.keyedvectors.Vocab at 0x1a39211438>,
#  '잔잔': <gensim.models.keyedvectors.Vocab at 0x1a392114a8>,
#  '이후': <gensim.models.keyedvectors.Vocab at 0x1a392114e0>,
#  '로빈': <gensim.models.keyedvectors.Vocab at 0x1a39211550>,
#  '01233441': <gensim.models.keyedvectors.Vocab at 0x1a39211588>,
#  '암스': <gensim.models.keyedvectors.Vocab at 0x1a39211160>,
#  '또': <gensim.models.keyedvectors.Vocab at 0x1a39211940>,
#  '다른': <gensim.models.keyedvectors.Vocab at 0x1a39211208>,
#  '도둑': <gensim.models.keyedvectors.Vocab at 0x1a39211080>,
#  '맞은': <gensim.models.keyedvectors.Vocab at 0x1a39211470>,
#  '00433675': <gensim.models.keyedvectors.Vocab at 0x1a39211518>,
#  '새로운': <gensim.models.keyedvectors.Vocab at 0x1a39211630>,
#  '""': <gensim.models.keyedvectors.Vocab at 0x1a39211668>,
#  '었': <gensim.models.keyedvectors.Vocab at 0x1a392116d8>,
#  '듯': <gensim.models.keyedvectors.Vocab at 0x1a39211710>,
#  '정점': <gensim.models.keyedvectors.Vocab at 0x1a39211780>,
#  '거지': <gensim.models.keyedvectors.Vocab at 0x1a392117f0>,
#  '넘치': <gensim.models.keyedvectors.Vocab at 0x1a39211828>,
#  '만점': <gensim.models.keyedvectors.Vocab at 0x1a39211898>,
#  '이었': <gensim.models.keyedvectors.Vocab at 0x1a392117b8>,
#  '유치': <gensim.models.keyedvectors.Vocab at 0x1a39211860>,
#  '재밌는': <gensim.models.keyedvectors.Vocab at 0x1a392118d0>,
#  '건': <gensim.models.keyedvectors.Vocab at 0x1a39211a90>,
#  '감독': <gensim.models.keyedvectors.Vocab at 0x1a392115c0>,
#  '감': <gensim.models.keyedvectors.Vocab at 0x1a392110f0>,
#  '때문': <gensim.models.keyedvectors.Vocab at 0x1a392112b0>,
#  '슬픔': <gensim.models.keyedvectors.Vocab at 0x1a39211278>,
#  '않': <gensim.models.keyedvectors.Vocab at 0x1a392119b0>,
#  '더욱': <gensim.models.keyedvectors.Vocab at 0x1a392119e8>,
#  '나이': <gensim.models.keyedvectors.Vocab at 0x1a39211a58>,
#  '엔': <gensim.models.keyedvectors.Vocab at 0x1a39211ac8>,
#  '뭐': <gensim.models.keyedvectors.Vocab at 0x1a39211b38>,
#  '닿지': <gensim.models.keyedvectors.Vocab at 0x1a392111d0>,
#  '01175227': <gensim.models.keyedvectors.Vocab at 0x1a39211a20>,
#  '이라는': <gensim.models.keyedvectors.Vocab at 0x1a392116a0>,
#  '밖에': <gensim.models.keyedvectors.Vocab at 0x1a39211978>,
#  '완벽한': <gensim.models.keyedvectors.Vocab at 0x1a39211908>,
#  '교과서': <gensim.models.keyedvectors.Vocab at 0x1a39211198>,
#  '절정': <gensim.models.keyedvectors.Vocab at 0x1a39211b70>,
#  '여기': <gensim.models.keyedvectors.Vocab at 0x1a39211be0>,
#  '크': <gensim.models.keyedvectors.Vocab at 0x1a39211c50>,
#  '답': <gensim.models.keyedvectors.Vocab at 0x1a39211c88>,
#  '바로': <gensim.models.keyedvectors.Vocab at 0x1a39211cf8>,
#  '스릴러': <gensim.models.keyedvectors.Vocab at 0x1a39211d68>,
#  '=': <gensim.models.keyedvectors.Vocab at 0x1a39211da0>,
#  '반전': <gensim.models.keyedvectors.Vocab at 0x1a39211e10>,
#  '00377748': <gensim.models.keyedvectors.Vocab at 0x1a39211e48>,
#  '완성': <gensim.models.keyedvectors.Vocab at 0x1a39211eb8>,
#  '해도': <gensim.models.keyedvectors.Vocab at 0x1a39211ef0>,
#  '지루함': <gensim.models.keyedvectors.Vocab at 0x1a39211f60>,
#  '이유': <gensim.models.keyedvectors.Vocab at 0x1a39211fd0>,
#  '없이': <gensim.models.keyedvectors.Vocab at 0x1a39211f28>,
#  '짜': <gensim.models.keyedvectors.Vocab at 0x1a39211dd8>,
#  '려는': <gensim.models.keyedvectors.Vocab at 0x1a39211f98>,
#  '작위': <gensim.models.keyedvectors.Vocab at 0x1a39211cc0>,
#  '성': <gensim.models.keyedvectors.Vocab at 0x1a39211e80>,
#  '어서': <gensim.models.keyedvectors.Vocab at 0x1a39211ba8>,
#  '이라': <gensim.models.keyedvectors.Vocab at 0x1a39211d30>,
#  '없는': <gensim.models.keyedvectors.Vocab at 0x1a39211748>,
#  '최강': <gensim.models.keyedvectors.Vocab at 0x1a39211c18>,
#  '인지': <gensim.models.keyedvectors.Vocab at 0x1a39211b00>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x1a39211320>,
#  '히어로': <gensim.models.keyedvectors.Vocab at 0x1a392113c8>,
#  '괜찮': <gensim.models.keyedvectors.Vocab at 0x1a392115f8>,
#  '재미': <gensim.models.keyedvectors.Vocab at 0x1a39214278>,
#  '주는': <gensim.models.keyedvectors.Vocab at 0x1a39214080>,
#  '어야': <gensim.models.keyedvectors.Vocab at 0x1a39214128>,
#  '책': <gensim.models.keyedvectors.Vocab at 0x1a392141d0>,
#  '권': <gensim.models.keyedvectors.Vocab at 0x1a392144a8>,
#  '느낌': <gensim.models.keyedvectors.Vocab at 0x1a392140b8>,
#  '종교': <gensim.models.keyedvectors.Vocab at 0x1a39214240>,
#  '관한': <gensim.models.keyedvectors.Vocab at 0x1a39214048>,
#  '시절': <gensim.models.keyedvectors.Vocab at 0x1a39214320>,
#  '어찌': <gensim.models.keyedvectors.Vocab at 0x1a39214390>,
#  '소년': <gensim.models.keyedvectors.Vocab at 0x1a392143c8>,
#  '록': <gensim.models.keyedvectors.Vocab at 0x1a39214438>,
#  '치': <gensim.models.keyedvectors.Vocab at 0x1a39214470>,
#  '않다': <gensim.models.keyedvectors.Vocab at 0x1a392144e0>,
#  '용': <gensim.models.keyedvectors.Vocab at 0x1a39214550>,
#  '날': <gensim.models.keyedvectors.Vocab at 0x1a392142b0>,
#  '여전하다': <gensim.models.keyedvectors.Vocab at 0x1a39214400>,
#  '긴': <gensim.models.keyedvectors.Vocab at 0x1a39214160>,
#  '동화': <gensim.models.keyedvectors.Vocab at 0x1a39214358>,
#  '미래': <gensim.models.keyedvectors.Vocab at 0x1a392140f0>,
#  '탄생': <gensim.models.keyedvectors.Vocab at 0x1a39214198>,
#  '아마': <gensim.models.keyedvectors.Vocab at 0x1a39214518>,
#  '엄청난': <gensim.models.keyedvectors.Vocab at 0x1a392142e8>,
#  '움': <gensim.models.keyedvectors.Vocab at 0x1a392145c0>,
#  '상상력': <gensim.models.keyedvectors.Vocab at 0x1a392145f8>,
#  '극': <gensim.models.keyedvectors.Vocab at 0x1a39214b38>,
#  '점': <gensim.models.keyedvectors.Vocab at 0x1a39214668>,
#  '환타지': <gensim.models.keyedvectors.Vocab at 0x1a392146d8>,
#  '쳐': <gensim.models.keyedvectors.Vocab at 0x1a39214710>,
#  '하게': <gensim.models.keyedvectors.Vocab at 0x1a39214780>,
#  '타': <gensim.models.keyedvectors.Vocab at 0x1a392147b8>,
#  '말할': <gensim.models.keyedvectors.Vocab at 0x1a39214828>,
#  '뮤지컬': <gensim.models.keyedvectors.Vocab at 0x1a39214860>,
#  '버린': <gensim.models.keyedvectors.Vocab at 0x1a392148d0>,
#  '속': <gensim.models.keyedvectors.Vocab at 0x1a39214908>,
#  '볼거리': <gensim.models.keyedvectors.Vocab at 0x1a39214978>,
#  '00394657': <gensim.models.keyedvectors.Vocab at 0x1a392149e8>,
#  '하': <gensim.models.keyedvectors.Vocab at 0x1a39214a20>,
#  '01046800': <gensim.models.keyedvectors.Vocab at 0x1a39214a90>,
#  '사랑스러운': <gensim.models.keyedvectors.Vocab at 0x1a39214ac8>,
#  '기념비': <gensim.models.keyedvectors.Vocab at 0x1a39214e80>,
#  '범죄': <gensim.models.keyedvectors.Vocab at 0x1a39214940>,
#  '울리는': <gensim.models.keyedvectors.Vocab at 0x1a392147f0>,
#  '이해': <gensim.models.keyedvectors.Vocab at 0x1a39214748>,
#  '공감': <gensim.models.keyedvectors.Vocab at 0x1a39214630>,
#  '놓': <gensim.models.keyedvectors.Vocab at 0x1a39214588>,
#  '뿐': <gensim.models.keyedvectors.Vocab at 0x1a39214b70>,
#  '공포': <gensim.models.keyedvectors.Vocab at 0x1a39214ba8>,
#  '01105453': <gensim.models.keyedvectors.Vocab at 0x1a39214c18>,
#  '다면': <gensim.models.keyedvectors.Vocab at 0x1a39214c50>,
#  '급': <gensim.models.keyedvectors.Vocab at 0x1a39214cc0>,
#  '청춘': <gensim.models.keyedvectors.Vocab at 0x1a39214d30>,
#  '지나도': <gensim.models.keyedvectors.Vocab at 0x1a39214da0>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x1a39214dd8>,
#  '한번': <gensim.models.keyedvectors.Vocab at 0x1a39214cf8>,
#  '하면': <gensim.models.keyedvectors.Vocab at 0x1a39214d68>,
#  '아까운': <gensim.models.keyedvectors.Vocab at 0x1a39214c88>,
#  '그대로': <gensim.models.keyedvectors.Vocab at 0x1a39214be0>,
#  '귀신': <gensim.models.keyedvectors.Vocab at 0x1a392146a0>,
#  '징': <gensim.models.keyedvectors.Vocab at 0x1a39214a58>,
#  '그러': <gensim.models.keyedvectors.Vocab at 0x1a39214ef0>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x1a39214eb8>,
#  '버전': <gensim.models.keyedvectors.Vocab at 0x1a39214898>,
#  '걸': <gensim.models.keyedvectors.Vocab at 0x1a39214f98>,
#  '단어': <gensim.models.keyedvectors.Vocab at 0x1a39214208>,
#  '져': <gensim.models.keyedvectors.Vocab at 0x1a39214f60>,
#  '정서': <gensim.models.keyedvectors.Vocab at 0x1a39214e10>,
#  '많이': <gensim.models.keyedvectors.Vocab at 0x1a392149b0>,
#  '오랜': <gensim.models.keyedvectors.Vocab at 0x1a39214b00>,
#  '했지만': <gensim.models.keyedvectors.Vocab at 0x1a39214fd0>,
#  '따뜻한': <gensim.models.keyedvectors.Vocab at 0x1a39214e48>,
#  '성장': <gensim.models.keyedvectors.Vocab at 0x1a39214f28>,
#  '기적': <gensim.models.keyedvectors.Vocab at 0x1a39217400>,
#  '순간': <gensim.models.keyedvectors.Vocab at 0x1a392170b8>,
#  '면목': <gensim.models.keyedvectors.Vocab at 0x1a39217160>,
#  '마이': <gensim.models.keyedvectors.Vocab at 0x1a39217208>,
#  '별로': <gensim.models.keyedvectors.Vocab at 0x1a392172b0>,
#  '인데': <gensim.models.keyedvectors.Vocab at 0x1a39217358>,
#  '가슴': <gensim.models.keyedvectors.Vocab at 0x1a39217240>,
#  '회': <gensim.models.keyedvectors.Vocab at 0x1a392173c8>,
#  '자': <gensim.models.keyedvectors.Vocab at 0x1a392172e8>,
#  '되': <gensim.models.keyedvectors.Vocab at 0x1a39217320>,
#  '00296878': <gensim.models.keyedvectors.Vocab at 0x1a392176d8>,
#  '분노': <gensim.models.keyedvectors.Vocab at 0x1a39217048>,
#  '케': <gensim.models.keyedvectors.Vocab at 0x1a392171d0>,
#  '와도': <gensim.models.keyedvectors.Vocab at 0x1a39217080>,
#  '개인': <gensim.models.keyedvectors.Vocab at 0x1a39217438>,
#  '오버': <gensim.models.keyedvectors.Vocab at 0x1a392174a8>,
#  '코': <gensim.models.keyedvectors.Vocab at 0x1a392174e0>,
#  '메': <gensim.models.keyedvectors.Vocab at 0x1a39217550>,
#  '디': <gensim.models.keyedvectors.Vocab at 0x1a392175c0>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x1a392175f8>,
#  '다르': <gensim.models.keyedvectors.Vocab at 0x1a39217668>,
#  '구나': <gensim.models.keyedvectors.Vocab at 0x1a392176a0>,
#  '영혼': <gensim.models.keyedvectors.Vocab at 0x1a39217710>,
#  '감정': <gensim.models.keyedvectors.Vocab at 0x1a39217748>,
#  '분위기': <gensim.models.keyedvectors.Vocab at 0x1a392177b8>,
#  '미': <gensim.models.keyedvectors.Vocab at 0x1a39217518>,
#  '연기력': <gensim.models.keyedvectors.Vocab at 0x1a39217c50>,
#  '부족': <gensim.models.keyedvectors.Vocab at 0x1a39217128>,
#  '아동': <gensim.models.keyedvectors.Vocab at 0x1a392170f0>,
#  '폭력': <gensim.models.keyedvectors.Vocab at 0x1a39217198>,
#  '딱': <gensim.models.keyedvectors.Vocab at 0x1a39217780>,
#  '장르': <gensim.models.keyedvectors.Vocab at 0x1a392177f0>,
#  '감성': <gensim.models.keyedvectors.Vocab at 0x1a37e05ac8>,
#  '년대': <gensim.models.keyedvectors.Vocab at 0x1a37e05eb8>,
#  '아픈': <gensim.models.keyedvectors.Vocab at 0x1a39217860>,
#  '상': <gensim.models.keyedvectors.Vocab at 0x1a39217898>,
#  '감탄': <gensim.models.keyedvectors.Vocab at 0x1a39217908>,
#  '!"': <gensim.models.keyedvectors.Vocab at 0x1a39217940>,
#  '0': <gensim.models.keyedvectors.Vocab at 0x1a392179b0>,
#  '장난': <gensim.models.keyedvectors.Vocab at 0x1a392179e8>,
#  '니다': <gensim.models.keyedvectors.Vocab at 0x1a39217a58>,
#  '가득한': <gensim.models.keyedvectors.Vocab at 0x1a39217a90>,
#  '가족': <gensim.models.keyedvectors.Vocab at 0x1a39217b00>,
#  '아이디어': <gensim.models.keyedvectors.Vocab at 0x1a39217b70>,
#  '드리': <gensim.models.keyedvectors.Vocab at 0x1a39217ba8>,
#  '죽어': <gensim.models.keyedvectors.Vocab at 0x1a39217ac8>,
#  '무섭': <gensim.models.keyedvectors.Vocab at 0x1a39217c18>,
#  '도록': <gensim.models.keyedvectors.Vocab at 0x1a39217b38>,
#  '후회': <gensim.models.keyedvectors.Vocab at 0x1a39217978>,
#  '억': <gensim.models.keyedvectors.Vocab at 0x1a392178d0>,
#  '01381372': <gensim.models.keyedvectors.Vocab at 0x1a39217390>,
#  '정신': <gensim.models.keyedvectors.Vocab at 0x1a39217588>,
#  '싶은': <gensim.models.keyedvectors.Vocab at 0x1a39217cc0>,
#  '멋있다': <gensim.models.keyedvectors.Vocab at 0x1a39217d68>,
#  '위해': <gensim.models.keyedvectors.Vocab at 0x1a39217d30>,
#  '약간': <gensim.models.keyedvectors.Vocab at 0x1a39217470>,
#  '아쉬움': <gensim.models.keyedvectors.Vocab at 0x1a39217cf8>,
#  '그저': <gensim.models.keyedvectors.Vocab at 0x1a39217e48>,
#  '형': <gensim.models.keyedvectors.Vocab at 0x1a39217c88>,
#  '써': <gensim.models.keyedvectors.Vocab at 0x1a39217828>,
#  '00000043': <gensim.models.keyedvectors.Vocab at 0x1a39217630>,
#  '수가': <gensim.models.keyedvectors.Vocab at 0x1a39217a20>,
#  '빠진': <gensim.models.keyedvectors.Vocab at 0x1a39217dd8>,
#  '진짜': <gensim.models.keyedvectors.Vocab at 0x1a39217e80>,
#  '하기': <gensim.models.keyedvectors.Vocab at 0x1a39217ef0>,
#  '힘든': <gensim.models.keyedvectors.Vocab at 0x1a39217f98>,
#  '가지': <gensim.models.keyedvectors.Vocab at 0x1a39217fd0>,
#  '으나': <gensim.models.keyedvectors.Vocab at 0x1a39217278>,
#  '싶네': <gensim.models.keyedvectors.Vocab at 0x1a39217da0>,
#  '을까': <gensim.models.keyedvectors.Vocab at 0x1a39217f60>,
#  '별': <gensim.models.keyedvectors.Vocab at 0x1a39217e10>,
#  'ㅠㅜ': <gensim.models.keyedvectors.Vocab at 0x1a39217f28>,
#  '!!': <gensim.models.keyedvectors.Vocab at 0x1a39217eb8>,
#  '01448826': <gensim.models.keyedvectors.Vocab at 0x1a39217be0>,
#  '배우': <gensim.models.keyedvectors.Vocab at 0x1a3921c358>,
#  '되었': <gensim.models.keyedvectors.Vocab at 0x1a3921c048>,
#  '일본': <gensim.models.keyedvectors.Vocab at 0x1a3921c0f0>,
#  '무': <gensim.models.keyedvectors.Vocab at 0x1a3921c198>,
#  '죄': <gensim.models.keyedvectors.Vocab at 0x1a3921c2b0>,
#  '합': <gensim.models.keyedvectors.Vocab at 0x1a3921c240>,
#  '타임': <gensim.models.keyedvectors.Vocab at 0x1a3921c320>,
#  '가볍': <gensim.models.keyedvectors.Vocab at 0x1a3921c1d0>,
#  '한데': <gensim.models.keyedvectors.Vocab at 0x1a3921c278>,
#  '센스': <gensim.models.keyedvectors.Vocab at 0x1a3921c2e8>,
#  '재': <gensim.models.keyedvectors.Vocab at 0x1a3921c208>,
#  '길': <gensim.models.keyedvectors.Vocab at 0x1a3921c128>,
#  '홀로': <gensim.models.keyedvectors.Vocab at 0x1a3921c0b8>,
#  '다는': <gensim.models.keyedvectors.Vocab at 0x1a3921c9b0>,
#  '거': <gensim.models.keyedvectors.Vocab at 0x1a3921c3c8>,
#  '빼고': <gensim.models.keyedvectors.Vocab at 0x1a3921c438>,
#  '알려': <gensim.models.keyedvectors.Vocab at 0x1a3921c470>,
#  '일단': <gensim.models.keyedvectors.Vocab at 0x1a3921c4e0>,
#  '전혀': <gensim.models.keyedvectors.Vocab at 0x1a3921c518>,
#  '아깝': <gensim.models.keyedvectors.Vocab at 0x1a3921c588>,
#  '선': <gensim.models.keyedvectors.Vocab at 0x1a3921c5c0>,
#  '보기': <gensim.models.keyedvectors.Vocab at 0x1a3921c630>,
#  '잔혹': <gensim.models.keyedvectors.Vocab at 0x1a3921c668>,
#  '펼': <gensim.models.keyedvectors.Vocab at 0x1a3921c6d8>,
#  '았': <gensim.models.keyedvectors.Vocab at 0x1a3921c710>,
#  '만에': <gensim.models.keyedvectors.Vocab at 0x1a3921c780>,
#  '충분한': <gensim.models.keyedvectors.Vocab at 0x1a3921c7b8>,
#  '부족함': <gensim.models.keyedvectors.Vocab at 0x1a3921c828>,
#  '스타': <gensim.models.keyedvectors.Vocab at 0x1a3921c860>,
#  '떠': <gensim.models.keyedvectors.Vocab at 0x1a3921c8d0>,
#  '~"': <gensim.models.keyedvectors.Vocab at 0x1a3921c908>,
#  '괴물': <gensim.models.keyedvectors.Vocab at 0x1a3921c7f0>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x1a3921c898>,
#  '하지': <gensim.models.keyedvectors.Vocab at 0x1a3921cc50>,
#  '몇': <gensim.models.keyedvectors.Vocab at 0x1a3921c6a0>,
#  '안되는': <gensim.models.keyedvectors.Vocab at 0x1a3921c550>,
#  '액션영화': <gensim.models.keyedvectors.Vocab at 0x1a3921c4a8>,
#  '그것': <gensim.models.keyedvectors.Vocab at 0x1a3921c390>,
#  '박수': <gensim.models.keyedvectors.Vocab at 0x1a3921c160>,
#  '류': <gensim.models.keyedvectors.Vocab at 0x1a3921c9e8>,
#  '무언가': <gensim.models.keyedvectors.Vocab at 0x1a3921ca58>,
#  '미쳤': <gensim.models.keyedvectors.Vocab at 0x1a3921ca90>,
#  '어': <gensim.models.keyedvectors.Vocab at 0x1a3921cb00>,
#  '첫': <gensim.models.keyedvectors.Vocab at 0x1a3921cb70>,
#  '굳이': <gensim.models.keyedvectors.Vocab at 0x1a3921cba8>,
#  '만들었': <gensim.models.keyedvectors.Vocab at 0x1a3921cac8>,
#  '과도': <gensim.models.keyedvectors.Vocab at 0x1a3921cc18>,
#  '죽음': <gensim.models.keyedvectors.Vocab at 0x1a3921cb38>,
#  '도전': <gensim.models.keyedvectors.Vocab at 0x1a3921c080>,
#  '다룬': <gensim.models.keyedvectors.Vocab at 0x1a3921cbe0>,
#  '밑': <gensim.models.keyedvectors.Vocab at 0x1a3921c5f8>,
#  '세상': <gensim.models.keyedvectors.Vocab at 0x1a3921ca20>,
#  '후': <gensim.models.keyedvectors.Vocab at 0x1a3921c978>,
#  '진정': <gensim.models.keyedvectors.Vocab at 0x1a3921c400>,
#  '느낄': <gensim.models.keyedvectors.Vocab at 0x1a3921cc88>,
#  '있던': <gensim.models.keyedvectors.Vocab at 0x1a3921c748>,
#  '깊은': <gensim.models.keyedvectors.Vocab at 0x1a3921ccf8>,
#  '맛': <gensim.models.keyedvectors.Vocab at 0x1a3921c940>,
#  '값': <gensim.models.keyedvectors.Vocab at 0x1a3921cd68>,
#  '생각나는': <gensim.models.keyedvectors.Vocab at 0x1a3921cdd8>,
#  '다소': <gensim.models.keyedvectors.Vocab at 0x1a3921ce80>,
#  '끼': <gensim.models.keyedvectors.Vocab at 0x1a3921cf28>,
#  '있어': <gensim.models.keyedvectors.Vocab at 0x1a3921ce48>,
#  '다행': <gensim.models.keyedvectors.Vocab at 0x1a3921cd30>,
#  '흥미롭': <gensim.models.keyedvectors.Vocab at 0x1a3921cfd0>,
#  '선장': <gensim.models.keyedvectors.Vocab at 0x1a3921ccc0>,
#  '제': <gensim.models.keyedvectors.Vocab at 0x1a3921cf60>,
#  '완벽하다': <gensim.models.keyedvectors.Vocab at 0x1a3921ceb8>,
#  '처럼': <gensim.models.keyedvectors.Vocab at 0x1a3921cf98>,
#  '뭔가': <gensim.models.keyedvectors.Vocab at 0x1a3921cda0>,
#  '필요하': <gensim.models.keyedvectors.Vocab at 0x1a3921ce10>,
#  '세계': <gensim.models.keyedvectors.Vocab at 0x1a3921cef0>,
#  '로는': <gensim.models.keyedvectors.Vocab at 0x1a3921e080>,
#  '집': <gensim.models.keyedvectors.Vocab at 0x1a3921e0f0>,
#  '데': <gensim.models.keyedvectors.Vocab at 0x1a3921e198>,
#  '21': <gensim.models.keyedvectors.Vocab at 0x1a3921e240>,
#  '머리': <gensim.models.keyedvectors.Vocab at 0x1a3921e2e8>,
#  '데도': <gensim.models.keyedvectors.Vocab at 0x1a3921e390>,
#  '뗄': <gensim.models.keyedvectors.Vocab at 0x1a3921e4a8>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x1a3921e320>,
#  '수도': <gensim.models.keyedvectors.Vocab at 0x1a3921e828>,
#  '환상': <gensim.models.keyedvectors.Vocab at 0x1a3921e278>,
#  '받': <gensim.models.keyedvectors.Vocab at 0x1a3921e128>,
#  '읽는': <gensim.models.keyedvectors.Vocab at 0x1a3921e2b0>,
#  '잇는': <gensim.models.keyedvectors.Vocab at 0x1a3921e208>,
#  '진심': <gensim.models.keyedvectors.Vocab at 0x1a3921e048>,
#  '기발': <gensim.models.keyedvectors.Vocab at 0x1a3921e3c8>,
#  '라니': <gensim.models.keyedvectors.Vocab at 0x1a3921e438>,
#  '킬링타임': <gensim.models.keyedvectors.Vocab at 0x1a3921e550>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x1a3921e588>,
#  '편도': <gensim.models.keyedvectors.Vocab at 0x1a3921e5f8>,
#  '00441493': <gensim.models.keyedvectors.Vocab at 0x1a3921e630>,
#  '리즈': <gensim.models.keyedvectors.Vocab at 0x1a3921e6a0>,
#  '뻔한': <gensim.models.keyedvectors.Vocab at 0x1a3921e6d8>,
#  '작': <gensim.models.keyedvectors.Vocab at 0x1a3921e748>,
#  '갑': <gensim.models.keyedvectors.Vocab at 0x1a3921e780>,
#  '다큐': <gensim.models.keyedvectors.Vocab at 0x1a3921e668>,
#  '변화': <gensim.models.keyedvectors.Vocab at 0x1a3921e7f0>,
#  '시키는': <gensim.models.keyedvectors.Vocab at 0x1a3921ec18>,
#  '열정': <gensim.models.keyedvectors.Vocab at 0x1a3921e4e0>,
#  '특히': <gensim.models.keyedvectors.Vocab at 0x1a3921e0b8>,
#  '충실': <gensim.models.keyedvectors.Vocab at 0x1a3921e400>,
#  '신화': <gensim.models.keyedvectors.Vocab at 0x1a3921e470>,
#  '채워': <gensim.models.keyedvectors.Vocab at 0x1a3921e1d0>,
#  '믿기': <gensim.models.keyedvectors.Vocab at 0x1a3921e860>,
#  '어려': <gensim.models.keyedvectors.Vocab at 0x1a3921e8d0>,
#  '00906718': <gensim.models.keyedvectors.Vocab at 0x1a3921e908>,
#  '마저': <gensim.models.keyedvectors.Vocab at 0x1a3921e978>,
#  '얼굴': <gensim.models.keyedvectors.Vocab at 0x1a3921e9b0>,
#  '아닌': <gensim.models.keyedvectors.Vocab at 0x1a3921ea20>,
#  '의미': <gensim.models.keyedvectors.Vocab at 0x1a3921ea58>,
#  '진화': <gensim.models.keyedvectors.Vocab at 0x1a3921eac8>,
#  '사': <gensim.models.keyedvectors.Vocab at 0x1a3921eb00>,
#  '팬': <gensim.models.keyedvectors.Vocab at 0x1a3921eb70>,
#  '화': <gensim.models.keyedvectors.Vocab at 0x1a3921ea90>,
#  '확실히': <gensim.models.keyedvectors.Vocab at 0x1a3921ebe0>,
#  '묵직': <gensim.models.keyedvectors.Vocab at 0x1a3921e940>,
#  '에의': <gensim.models.keyedvectors.Vocab at 0x1a3921e518>,
#  '진부': <gensim.models.keyedvectors.Vocab at 0x1a3921e358>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x1a3921e5c0>,
#  '줬': <gensim.models.keyedvectors.Vocab at 0x1a3921e7b8>,
#  '맞는': <gensim.models.keyedvectors.Vocab at 0x1a3921ec50>,
#  '깨닫': <gensim.models.keyedvectors.Vocab at 0x1a3921ec88>,
#  '낫다': <gensim.models.keyedvectors.Vocab at 0x1a3921ecf8>,
#  ';': <gensim.models.keyedvectors.Vocab at 0x1a3921ed30>,
#  '상처': <gensim.models.keyedvectors.Vocab at 0x1a3921eda0>,
#  '초': <gensim.models.keyedvectors.Vocab at 0x1a3921edd8>,
#  '~!': <gensim.models.keyedvectors.Vocab at 0x1a3921ee48>,
#  '다만': <gensim.models.keyedvectors.Vocab at 0x1a3921eeb8>,
#  '00134881': <gensim.models.keyedvectors.Vocab at 0x1a3921eef0>,
#  '에서도': <gensim.models.keyedvectors.Vocab at 0x1a3921ef60>,
#  '담': <gensim.models.keyedvectors.Vocab at 0x1a3921ef98>,
#  '간': <gensim.models.keyedvectors.Vocab at 0x1a3921ee80>,
#  '평생': <gensim.models.keyedvectors.Vocab at 0x1a3921ee10>,
#  '어머니': <gensim.models.keyedvectors.Vocab at 0x1a3921ef28>,
#  '세월': <gensim.models.keyedvectors.Vocab at 0x1a3921ecc0>,
#  '편이': <gensim.models.keyedvectors.Vocab at 0x1a3921efd0>,
#  '는데': <gensim.models.keyedvectors.Vocab at 0x1a3921e160>,
#  '더라': <gensim.models.keyedvectors.Vocab at 0x1a3921e9e8>,
#  '들어': <gensim.models.keyedvectors.Vocab at 0x1a3921ed68>,
#  '싶': <gensim.models.keyedvectors.Vocab at 0x1a3921e898>,
#  '막': <gensim.models.keyedvectors.Vocab at 0x1a3921e710>,
#  '여러': <gensim.models.keyedvectors.Vocab at 0x1a3921eb38>,
#  '즐겁': <gensim.models.keyedvectors.Vocab at 0x1a3921eba8>,
#  '과거': <gensim.models.keyedvectors.Vocab at 0x1a392223c8>,
#  '만남': <gensim.models.keyedvectors.Vocab at 0x1a392220b8>,
#  '있으': <gensim.models.keyedvectors.Vocab at 0x1a392221d0>,
#  '그냥': <gensim.models.keyedvectors.Vocab at 0x1a39222278>,
#  '라고': <gensim.models.keyedvectors.Vocab at 0x1a39222320>,
#  '엉': <gensim.models.keyedvectors.Vocab at 0x1a39222358>,
#  '대': <gensim.models.keyedvectors.Vocab at 0x1a39222390>,
#  '한계': <gensim.models.keyedvectors.Vocab at 0x1a392222e8>,
#  '어디': <gensim.models.keyedvectors.Vocab at 0x1a39222048>,
#  '희': <gensim.models.keyedvectors.Vocab at 0x1a39222080>,
#  '봅': <gensim.models.keyedvectors.Vocab at 0x1a39222470>,
#  '치고': <gensim.models.keyedvectors.Vocab at 0x1a39222518>,
#  '보아': <gensim.models.keyedvectors.Vocab at 0x1a392225c0>,
#  '야': <gensim.models.keyedvectors.Vocab at 0x1a39222668>,
#  '간만': <gensim.models.keyedvectors.Vocab at 0x1a39222710>,
#  '네': <gensim.models.keyedvectors.Vocab at 0x1a392224a8>,
#  '00446488': <gensim.models.keyedvectors.Vocab at 0x1a39222588>,
#  '+': <gensim.models.keyedvectors.Vocab at 0x1a392220f0>,
#  '흐르는': <gensim.models.keyedvectors.Vocab at 0x1a39222240>,
#  '만은': <gensim.models.keyedvectors.Vocab at 0x1a39222a20>,
#  '보다는': <gensim.models.keyedvectors.Vocab at 0x1a39222198>,
#  '만들기': <gensim.models.keyedvectors.Vocab at 0x1a39222630>,
#  '배신': <gensim.models.keyedvectors.Vocab at 0x1a39222160>,
#  '영화로': <gensim.models.keyedvectors.Vocab at 0x1a392224e0>,
#  '임': <gensim.models.keyedvectors.Vocab at 0x1a39222550>,
#  '과연': <gensim.models.keyedvectors.Vocab at 0x1a39222780>,
#  '세': <gensim.models.keyedvectors.Vocab at 0x1a39222208>,
#  '얼': <gensim.models.keyedvectors.Vocab at 0x1a392226a0>,
#  '않고': <gensim.models.keyedvectors.Vocab at 0x1a392227f0>,
#  '효과': <gensim.models.keyedvectors.Vocab at 0x1a39222828>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x1a39222898>,
#  '00076489': <gensim.models.keyedvectors.Vocab at 0x1a392228d0>,
#  '동심': <gensim.models.keyedvectors.Vocab at 0x1a39222940>,
#  '순수한': <gensim.models.keyedvectors.Vocab at 0x1a39222978>,
#  '기분': <gensim.models.keyedvectors.Vocab at 0x1a392229b0>,
#  '싸움': <gensim.models.keyedvectors.Vocab at 0x1a39222cf8>,
#  '말고': <gensim.models.keyedvectors.Vocab at 0x1a39222128>,
#  '지루': <gensim.models.keyedvectors.Vocab at 0x1a39222400>,
#  '후반': <gensim.models.keyedvectors.Vocab at 0x1a392222b0>,
#  '부': <gensim.models.keyedvectors.Vocab at 0x1a392225f8>,
#  '01161235': <gensim.models.keyedvectors.Vocab at 0x1a39222748>,
#  '최대': <gensim.models.keyedvectors.Vocab at 0x1a39222a90>,
#  '몰랐': <gensim.models.keyedvectors.Vocab at 0x1a39222b00>,
#  '믿': <gensim.models.keyedvectors.Vocab at 0x1a39222b38>,
#  '성공': <gensim.models.keyedvectors.Vocab at 0x1a39222ba8>,
#  '아프': <gensim.models.keyedvectors.Vocab at 0x1a39222c18>,
#  '01288974': <gensim.models.keyedvectors.Vocab at 0x1a39222c50>,
#  '01130407': <gensim.models.keyedvectors.Vocab at 0x1a39222b70>,
#  '않지': <gensim.models.keyedvectors.Vocab at 0x1a39222cc0>,
#  '되는': <gensim.models.keyedvectors.Vocab at 0x1a39222be0>,
#  '선생님': <gensim.models.keyedvectors.Vocab at 0x1a39222a58>,
#  '문제': <gensim.models.keyedvectors.Vocab at 0x1a39222c88>,
#  '느껴지': <gensim.models.keyedvectors.Vocab at 0x1a392226d8>,
#  '굉장히': <gensim.models.keyedvectors.Vocab at 0x1a39222ac8>,
#  '있지': <gensim.models.keyedvectors.Vocab at 0x1a39222438>,
#  '그다지': <gensim.models.keyedvectors.Vocab at 0x1a39222908>,
#  '영상': <gensim.models.keyedvectors.Vocab at 0x1a392227b8>,
#  '누구': <gensim.models.keyedvectors.Vocab at 0x1a39222d30>,
#  '소중한': <gensim.models.keyedvectors.Vocab at 0x1a39222d68>,
#  '에는': <gensim.models.keyedvectors.Vocab at 0x1a39222dd8>,
#  '내용': <gensim.models.keyedvectors.Vocab at 0x1a39222e48>,
#  '..."': <gensim.models.keyedvectors.Vocab at 0x1a39222e80>,
#  '인물': <gensim.models.keyedvectors.Vocab at 0x1a39222ef0>,
#  '보인': <gensim.models.keyedvectors.Vocab at 0x1a39222f28>,
#  '00102700': <gensim.models.keyedvectors.Vocab at 0x1a39222f98>,
#  '문화': <gensim.models.keyedvectors.Vocab at 0x1a39222fd0>,
#  '몸': <gensim.models.keyedvectors.Vocab at 0x1a39222e10>,
#  '은데': <gensim.models.keyedvectors.Vocab at 0x1a39222eb8>,
#  '지루하고': <gensim.models.keyedvectors.Vocab at 0x1a39222f60>,
#  '없네': <gensim.models.keyedvectors.Vocab at 0x1a39222da0>,
#  '정의': <gensim.models.keyedvectors.Vocab at 0x1a39222860>,
#  '걍': <gensim.models.keyedvectors.Vocab at 0x1a392229e8>,
#  '과학': <gensim.models.keyedvectors.Vocab at 0x1a39226048>,
#  '운명': <gensim.models.keyedvectors.Vocab at 0x1a39226080>,
#  '어떻': <gensim.models.keyedvectors.Vocab at 0x1a392260b8>,
#  '무려': <gensim.models.keyedvectors.Vocab at 0x1a392260f0>,
#  '01192492': <gensim.models.keyedvectors.Vocab at 0x1a39226128>,
#  '00221200': <gensim.models.keyedvectors.Vocab at 0x1a39226160>,
#  '안보': <gensim.models.keyedvectors.Vocab at 0x1a39226198>,
#  '이고': <gensim.models.keyedvectors.Vocab at 0x1a392261d0>,
#  '멋': <gensim.models.keyedvectors.Vocab at 0x1a39226208>,
#  '만큼은': <gensim.models.keyedvectors.Vocab at 0x1a39226240>,
#  '제목': <gensim.models.keyedvectors.Vocab at 0x1a39226278>,
#  '없어': <gensim.models.keyedvectors.Vocab at 0x1a392262b0>,
#  '아쉬운': <gensim.models.keyedvectors.Vocab at 0x1a392262e8>,
#  '깊이': <gensim.models.keyedvectors.Vocab at 0x1a39226320>,
#  '참신': <gensim.models.keyedvectors.Vocab at 0x1a39226358>,
#  '01362660': <gensim.models.keyedvectors.Vocab at 0x1a39226390>,
#  '이제': <gensim.models.keyedvectors.Vocab at 0x1a392263c8>,
#  '아닐': <gensim.models.keyedvectors.Vocab at 0x1a39226400>,
#  '라서': <gensim.models.keyedvectors.Vocab at 0x1a39226438>,
#  '넘': <gensim.models.keyedvectors.Vocab at 0x1a39226470>,
#  '00176365': <gensim.models.keyedvectors.Vocab at 0x1a392264a8>,
#  '이하': <gensim.models.keyedvectors.Vocab at 0x1a392264e0>,
#  '면서': <gensim.models.keyedvectors.Vocab at 0x1a39226518>,
#  '보지': <gensim.models.keyedvectors.Vocab at 0x1a39226550>,
#  '나라': <gensim.models.keyedvectors.Vocab at 0x1a39226588>,
#  '울컥': <gensim.models.keyedvectors.Vocab at 0x1a392265c0>,
#  '어요': <gensim.models.keyedvectors.Vocab at 0x1a392265f8>,
#  '스케일': <gensim.models.keyedvectors.Vocab at 0x1a39226630>,
#  '쯤': <gensim.models.keyedvectors.Vocab at 0x1a39226668>,
#  '어린': <gensim.models.keyedvectors.Vocab at 0x1a392266a0>,
#  '양': <gensim.models.keyedvectors.Vocab at 0x1a392266d8>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x1a39226710>,
#  '우주': <gensim.models.keyedvectors.Vocab at 0x1a39226748>,
#  '피': <gensim.models.keyedvectors.Vocab at 0x1a39226780>,
#  '다고': <gensim.models.keyedvectors.Vocab at 0x1a392267b8>,
#  '봄': <gensim.models.keyedvectors.Vocab at 0x1a392267f0>,
#  '겨울': <gensim.models.keyedvectors.Vocab at 0x1a39226828>,
#  '표현': <gensim.models.keyedvectors.Vocab at 0x1a39226860>,
#  '자꾸': <gensim.models.keyedvectors.Vocab at 0x1a39226898>,
#  '따위': <gensim.models.keyedvectors.Vocab at 0x1a392268d0>,
#  '왠지': <gensim.models.keyedvectors.Vocab at 0x1a39226908>,
#  '만의': <gensim.models.keyedvectors.Vocab at 0x1a39226940>,
#  '그녀': <gensim.models.keyedvectors.Vocab at 0x1a39226978>,
#  '진실': <gensim.models.keyedvectors.Vocab at 0x1a392269b0>,
#  '아쉽': <gensim.models.keyedvectors.Vocab at 0x1a392269e8>,
#  '낭만': <gensim.models.keyedvectors.Vocab at 0x1a39226a20>,
#  '00455617': <gensim.models.keyedvectors.Vocab at 0x1a39226a58>,
#  '달': <gensim.models.keyedvectors.Vocab at 0x1a39226a90>,
#  '그럼': <gensim.models.keyedvectors.Vocab at 0x1a39226ac8>,
#  '00142408': <gensim.models.keyedvectors.Vocab at 0x1a39226b00>,
#  '이군': <gensim.models.keyedvectors.Vocab at 0x1a39226b38>,
#  '^^': <gensim.models.keyedvectors.Vocab at 0x1a39226b70>,
#  '라면': <gensim.models.keyedvectors.Vocab at 0x1a39226ba8>,
#  '압권': <gensim.models.keyedvectors.Vocab at 0x1a39226be0>,
#  '번': <gensim.models.keyedvectors.Vocab at 0x1a39226c18>,
#  '부족한': <gensim.models.keyedvectors.Vocab at 0x1a39226c50>,
#  '주인공': <gensim.models.keyedvectors.Vocab at 0x1a39226c88>,
#  '무서운': <gensim.models.keyedvectors.Vocab at 0x1a39226cc0>,
#  '사운드': <gensim.models.keyedvectors.Vocab at 0x1a39226cf8>,
#  ...}
