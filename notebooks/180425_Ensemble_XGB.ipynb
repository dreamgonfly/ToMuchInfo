# %%
import os
import sys
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

sys.path.append("../code/")
from dictionaries import Word2VecDictionary
from tokenizers import TwitterTokenizer

# %%
with open("../code/data/small/train/train_data") as f:
    reviews = f.readlines()

# %%
class Config:
    max_vocab_size = 10
    min_count = 1
    vocabulary_size = 3000 
    embedding_size = 200

# %%
tokenizer = TwitterTokenizer(Config)

# %%
tokenized_reviews = [tokenizer.tokenize(review) for review in reviews]

# %%
tokens = [[token for token, tag in tokenized_review] for tokenized_review in tokenized_reviews]

# %%
vectorizer = Word2VecDictionary(TwitterTokenizer, Config)

# %%
data = [(review, 0) for review in reviews]

# %%
vectorizer.build_dictionary(data)

# %%
vectorizer.indexer("영화")
# Out:
# 8

# %%
tfidf = TfidfVectorizer()

# %%
tfidf.fit(reviews)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
from soynlp.tokenizer import MaxScoreTokenizer
from soynlp.word import WordExtractor

# %%
extractor = WordExtractor(reviews)
# Out:
# training was done. used memory 0.090 Gb

# %%
scores = extractor.word_scores()
# Out:
# all cohesion probabilities was computed. # words = 4687
# all branching entropies was computed # words = 7005
# all accessor variety was computed # words = 7005

# %%
scores['안'].
# Out:
# 0

# %%
# Out:
# dict_keys(['몰입', '있을까?', '81', '진ac01266', '해요', '였던', '는내내', '밀', '성.', '같은데', '는데', '지,', '없다...', '이렇', '험', '필요없', '디의', '졌던', '하다.', '요한가', '사랑은', 'ac0146', '뭐야', '데', '당신', '외계', '상어', 'day', '296878', '기에', '계인', 'ac013426', '왔으면', '시작', '계를', 'ac0123344', '기', '입니다..', '적으로', '판', '198', '예', 'mv004200', '6언', '편', '진ac012660', '5편', '길이', '70', '생생', '아이들', '재미있었다', '활', '편안', 'ac01192', '족의', '내리', '들어도', '아.', '최고다.', '!!!!', '들을', '뮤지', '유명한', '현', '느껴', '심이', '케빈과', '런영화가', '50', '대표작', '에게', '자유를', '흥행', '면.', 'mv0005', '급', '1372', '몸', '디즈니', '2254!', '배우들', '도', '우울', 'mv0033', '??', '또한', '유쾌', '02700의', '잊지못', '처음으', '6365', 'm', '전에', '는', '봤네', '캡틴.', '에서도', '만들어진', '큼은', 'mv00355558', '화치고는', '그러나', 'ac0001', 'ac002', '뿐', '화관에서', '좋아요', '았다', '밌다.', '화라니', '조낸', 'mv003571', '접', '가슴을', '오드리햅번', '55.', '12', '데,', '전편을', 'ac01185190', '탄생시', '스는', '니...', '생각보다', '기억', '나오', '장감', '명작', '싸움', '락영화의', '니다.', '"너', '나왔다', '것.', '94', '언', 'mv0039003', '모험영화', '여주는
# ...

# %%
tokenizer = MaxScoreTokenizer(scores=scores)

# %%
tokenizer.tokenize("이 영화가 최고야")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-0f74b5f600d7> in <module>()
# ----> 1 tokenizer.tokenize("이 영화가 최고야")
#
# /usr/local/lib/python3.6/site-packages/soynlp/tokenizer/_tokenizer.py in tokenize(self, sentence, flatten)
#     131
#     132     def tokenize(self, sentence, flatten=True):
# --> 133         tokens = [self._recursive_tokenize(token) for token in sentence.split()]
#     134         if flatten:
#     135             tokens = [subtoken[0] for token in tokens for subtoken in token]
#
# /usr/local/lib/python3.6/site-packages/soynlp/tokenizer/_tokenizer.py in <listcomp>(.0)
#     131
#     132     def tokenize(self, sentence, flatten=True):
# --> 133         tokens = [self._recursive_tokenize(token) for token in sentence.split()]
#     134         if flatten:
# ...
