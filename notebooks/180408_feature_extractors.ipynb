# %% [markdown]
# # 180408_feature_extractors

# %% [markdown]
# ## 구현해볼 것들

# %% [markdown]
# - SentimentExtractor
# - TfidfExtractor
# - SentenceVectorizer
# - ImportantWordsExtractor
# - ScoreExpressionExtractor

# %%
from feature_extractors import ScoreExpressionExtractor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-2edc3ad3b920> in <module>()
# ----> 1 from feature_extractors import ScoreExpressionExtractor
#
# ImportError: cannot import name 'ScoreExpressionExtractor'

# %%
import os
import pickle
import sys
import warnings
import pandas as pd

class DummyFeatureExtractor:
    """
    Base dummy feature extractor
    """
    def extract_feature(self, raw_text, tokenized_text):
        """
        :params raw_text: raw text
        :params tokenized_text: tokenized text, it should be space seperated or list
        """
        return "tuple"

# %%
with open("../data/movie.txt") as f:
    data = f.readlines()
    data = [str(t.strip()) for t in data]
    data = pd.DataFrame(data, columns=['comment'])
    
with open("../data/movie_label.txt") as f:
    score = f.readlines()
    data['score'] = pd.DataFrame(score)
    data['score'] = data['score'].map(lambda x: int(x.strip()))

# %%
pd.set_option("Display.max_rows",100)

# %%
data.iloc[:10000]
# Out:
#                                                 comment  score
# 0                               아련한 향수를 떠올리게 만드는 추억의 영화      8
# 1                              SF 코미디 영화사에서 가장 주목해야할 영화      9
# 2                        mv00036133의 꿈이 고스란히 담겨진 최고의 영화      8
# 3                                전편을 120% 활용하는 천재적인 속편.      9
# 4                                1편만큼 재미있다. 3편만 조금 떨어짐.      8
# 5                               역시 전편을 능가하는 속편은 지극히 드물다      7
# 6                                        무슨 설명이 더 필요한가?     10
# 7                     mv00501003라는 이름만으로도 설레게 만드는 영화의 힘     10
# 8                                이때참 ac00000559가 멋져 보였지      9
# 9                                    시원하면서도 심장을 꽉 조여온다.     10
# 10                        mv00457204에 계속해줘도 계속보게 만드는 영화      9
# 11                        mv00457204에 만나는 mv00390115 캐빈      9
# 12                    mv00457204 시즌이면 항상 가장먼저 떠오르는 가족영화      8
# 13                   '둘리'와 함께 언제고 mv00457201도 즐거운 '케빈'.      9
# 14                               E.T 같은 친구 한 명만 있었으면...     10
# 15                            영원한 스칼렛으로 기억 될 ac00939862     10
# 16                                   록키 시리즈를 통틀어 최고!!!!      7
# 17                       전개와 결말이 보였던 영화. 그래도 감동 있었던 영화.      7
# 18                                    별도의 수식어가 필요없는 영화.      9
# 19                       "mv00000082 시리즈의 시작, 전설의 근원지점"      7
# 20         "오래된 영화ac00920758, 모든 mv00335020물의 아버지격인 영화"      7
# 21                                   말이 필요없는 최고의 SF명작영화     10
# 22                    ac00001858 최고의 걸작은 <mv00000112>다!     10
# 23                             끔찍했지만 정말 재밌었다. 멋진 여전사 굿!      9
# 24                          자유를 향한 끝없는 집념은 없던 희망도 만들어낸다      8
# 25                        현실과 이상을 넘어선 참된 교육의 표본을 보여준 영화      9
# 26                                 우리에겐 여전히 결핍된 참교육....      9
# 27                                     내 인생 최고의 영화 중 하나      9
# 28                                설명이 필요없다. mv00230755.      9
# 29                       너무 길다. 그래도 대작 서사시로서의 가치는 충분하다.      7
# 30                             투명 외계인이 나오는 시원시원스러운 오락물.      7
# 31                                       클래식은 영원히 빛나는 법     10
# 32                               남자들을 위mv00416725들의 이야기      8
# 33                        1편에 버금가는 2편을 볼 수 있음을 증명한다....      9
# 34                                        기대가 너무 컸나?;;;      4
# 35                        오드리 햅번의 mv00326143이 영화의 전부였다.      9
# 36                          '영화가 왜 종합 예술인가'라는 질문에 대한 답변     10
# 37                                   감동과 스릴과 음악이 있는 명작!      9
# 38                               남자의 허세가 이토록 아름다울 수 있다니      8
# 39                                           홍콩 느와르의 진수      9
# 40                             ac00022345를 누가 연기하느냐에 따라      5
# 41                                               죠스의 활약      7
# 42                                       007판 모험이란 이런것.      7
# 43                              다양한 이분법적 요소로 빚어낸 사랑의 원형      8
# 44                                         역시 원조는 원조 ㅋㅋ      8
# 45                          20년이 지난 지금도 여전히 손에 땀을 쥐게 한다      9
# 46                                  아직 이만한 속편이 나오질 못했다.      9
# 47                                전편보다 나은 속편. 레전드 그 자체.     10
# 48                                      히치콕판 '나는 상업영화다'     10
# 49                          ac00002593의 성찰과 용기가 돋보이는 작품      7
# 50                        놀랍게도 그의 웃음과 풍자(비판)는 아직까지 통한다!     10
# 51                           조금이라도 놓칠새라 눈을 떼지않았던 멋진 고전!      9
# 52                          mv00185524 투숏을 보여주는 마지막 장면.     10
# 53                        황홀함을 느끼게 하는 스필버그의 뛰어난 연출이 돋보임      8
# 54                                         허한 여운을 남긴 걸작      9
# 55                                          한국적 캐릭터의 힘!      9
# 56                "누아르와 신비주의의 결합, ac00887011게도 끌리질 않는다"      5
# 57                 어릴적 극장에 가서 봤던 영화. ac01074895고 재미있었다.      8
# 58                                케시베이츠를 있게 해준 최고의 스릴러물      9
# 59                                인류역사상 가장 위대한 영화의 화룡점정      8
# 60                          어른들의 마음 한 구석을 찌르는 가시가 숨어있다.      8
# 61               허무와 절망은 지금 내 존재의 끝이 아니라 진ac01266023 출발     10
# 62                         갱영화 싫어하는 사람도 몰입해서 볼 수 있는 영화.      8
# 63                       "너무나 예뻤던 ac00005578, 홍콩영화의 수작"      8
# 64                          이 영화를 보고 ac00643771에 반했다...      8
# 65                               mv00110329 어른들의 축소판이다.      8
# 66                                      스콜세지 스타일의 모든 것.     10
# 67                                           뭐라 할말이 없다.      8
# 68             ac01233717과 ac01318447뎁의 합작 중 가장 인상적인 영화      9
# 69                그 어떤 영화에서보다 가위손에서의 ac01318447뎁은 최고였다.      8
# 70                             드 니로의 마지막 표정을 잊을 수 없다...     10
# 71                        단순한 B무비가 아니다. 스콜세지의 철학을 느껴보자.      8
# 72                                 액션과 멜로가 적절히 혼합된 상업영화      7
# 73                                여전히 그리운 영화 mv00144316      8
# 74                        사회밖에서 더 mv00217576 mv00401824      8
# 75                               한국의 미켈란젤로 mv00428851니!      9
# 76                                       나만 너무 재밌나보다...      9
# 77                       1편보다 못ac00477430 그렇게 나쁘지도 않았다.      8
# 78                               "소설도,영화도 연극도 모두 흥미로왔다"      9
# 79      "mv00355558 폭발하는 ac00643771, 밀리지 않는 ac00004657"      8
# 128                        추천! 멋진 영화. 마지막 장면이 아직도 기억난다.      9
# 129                             10점도 모자르다. 점수를 더 주고 싶다.     10
# 130                                        무난한 가족영화....      6
# 131                               완전 재밌고 흥미로왔던 모험판타지 영화      8
# 132                  ac00001054의 출연작은 역시 관객을 실망시키지 않는다.      8
# 133                        mv00198709를 뇌리에 깊게 새기게 만든 영화      9
# 134                     청소년아이들이 꼭 봤으면 좋을 mv00217576 영화~      9
# 135                    "처음으로, 동생과 함께 수건 하나씩 적시며 보았던 영화"     10
# 136                      감동적ac00920758 결말이 매우 아쉬웠던 슬픈영화      8
# 137                      브ac00782011 mv00382036의 히치콕 본능      9
# 138                         이 영화에서 매력적이지 않은것을 찾아보기란 힘들다      9
# 139                         mv00457204의 상업적인 면모를 비꼬는 영화      6
# 140                                     실화를 바탕으로한 일급스토리      9
# 141                                 자연은 언제나 인간에게 감동을 준다      8
# 142                        "달달하고 따뜻하다, 해서 편안히 볼만하다..^^"      7
# 143                       그 모든 것이 사랑하고 즐길수 없다면 아무것도 아니다      8
# 144                                    조금 현실적인 <쥬라기 공원>      8
# 145                                     재밌다. 정말. 그거면 된다     10
# 146                       "인간에게 버림 받은 여자, 신에게 구원 받은 여자"      9
# 147                   ac01436025의 연출력이 돋보이는 최고의 코믹호러영화!      9
# 148                    "뛰어난 긴장감.심리묘사,저예산으로도 만들수 있다는 모범"      8
# 149                          ac00005938의 영화는 언제나 익살스럽다.      8
# 150                    왜 헐리웃에만 가면 ac00432043지는 것일까.....      6
# 151                     "놀라운 소재. 스릴,연출 역시 ac00005548이다"      7
# 152                           시대의 비극.. ac00024886.. 아..      7
# 153                                   영화적이라기보다 문학적인 SF.      7
# 154                                   아기자기 유쾌발랄.귀여운 토토로      8
# 155                          미야자키 영화는 언제나 멋지고 생각하게끔 한다.      8
# 156               "꽤 오래 전 영화ac00920758, 재밌고 볼만한 로코..^^"      7
# 157                              명작의 감동은 때와 장소를 가리지 않는다     10
# 158                               감히 전설이 될 수 있는 로맨스 영화.      9
# 159                      얼마나 울면서 봤던지.. 주제곡 들으면 아직도 눈물나요      9
# 160                                    3시간이 이렇게 빨리갈줄이야.      9
# 161                          OST가 잊혀지지 않는 mv00217576 영화      9
# 162                       ac01370484 영화중 내가 가장 사랑하는 작품.     10
# 163               무엇을 위한 전쟁인가를 상징적으로 보여준 ac00782011 일병.      7
# 164                                    화려한 출연진 만큼 화끈하다.      8
# 165                        너무나 mv00217576 영화. 오겡끼데스까...      9
# 166          "CF보다 멋있는 영화, mv00107434보다 mv00217576 영화."     10
# 167                                우성과 열성의 차이는 노력의 차이다.      8
# 168                                       차분하고 잔잔한 드라마.      7
# 169            "mv00000142 이후, 로빈 ac01233441암스의 또다른 수작"      8
# 170                     "도둑맞은 인생, 코미디가 아니라 mv00433675다"      8
# 171                         "새로운 디즈니는 ""뮬란""에서 끝났었던 듯."      9
# 172                                  ac00001624 월드의 정점.      9
# 173                           ac00001624식 자연주의의 끝을 보여준다     10
# 174                               ac00000598는 무슨 능력인거지?      9
# 175                                 완전 스릴넘치고 흥미만점이었던 영화      8
# 176               유치ac00477430 끝까지 재밌는건 순전히 감독의 좋은 감 때문      7
# 177                                   이 영화가 mv00165583!     10
# 178                          슬픔은 표현하지 않을 때 더욱 슬퍼진다.....      9
# 179        헉...ac01174141 ac01136836 주연의 ac00953617줄...      4
# 180                                 내가 저 나이엔 뭐하고 있었나...      8
# 181                 닿지 못할 ac01175227 감동을 주거나 쓴웃음을 남기거나.      7
# 182                          역시 mv00361969 노튼 이라는 말밖에..      9
# 183                                연출이 완벽한 영화. SF의 교과서.     10
# 184                                  ac00141505 코드의 절정.      9
# 185                                         여기서 끝내야 했다.     10
# 186                           신체 훼손의 끝까진 아니여도 크로넨버그 답다.      6
# 187                                    이게 바로 MTV 스타일이다.      9
# 188                              '스릴러 = 반전영화'로 만든 나쁜영화!     10
# 189                             럼펄스틸스킨 캐릭터만 mv00377748.      4
# 190                           다케시 스타일의 완성체라고 해도 과언이 아니다      8
# 191                                  오로지 ac00001690의 영화      8
# 192                                         사랑이 만병통치약이다     10
# 193                                  지루함을 잊게 하는 사랑의 설레임      7
# 194                                       애니메이션 속편의 모범례      8
# 195                                     이유없이 태어난 생명은 없다      7
# 196                               감동을 짜내려는 작위성이 여운을 흐린다      7
# 197                             이 영화는 사랑에 있어서의 시간을 말한다.      9
# 198                      비현실적이라 더욱 아름다웠던 mv00329092의 일생      9
# 199                                눈 돌릴 틈 없는 액션. 몰입 최강.      9
# 200                  ac01224051이 왜 거장인지 제대로 mv00067518.     10
# 201                   단순히 mv00374113들의 히어로물로 치부해서는 안된다.      9
# 202                        전형적ac00920758 괜찮은 재미를 주는 영화.      7
# 203                                       1편에서 그쳤어야 했다.      4
# 204                                  좋은 소설책 한권 읽은 느낌이다.      8
# 205                       종교와 삶에 관한 감독의 유년시절을 어렴풋이 투영하다      6
# 206                         이 사랑을 어찌잊을까요? 어찌 잊을 수 있을까요?      9
# 207                        "꿈을 이룬 소년, 그러나 현실은 녹록치 않다.."      8
# 208                                  아카데미가 외면한 아카데미용 영화      6
# 209                                    서극의 날샌 스타일은 여전하다      9
# 210                                            삶에 대한 고찰      8
# 211                                       실루엣 애니메이션의 매력      6
# 212                   긴 호흡과 ac01317645함을 간직한 동화같은 미래이야기      8
# 213                 새로운 mv00335020물의 탄생의 기대에 의구심을 품게 하다      6
# 214                         아마 지금 잭슨 폴락의 그림이 엄청난 고가라지..      7
# 215                               한국 대형 애니에 대한 안타까움의 종합      7
# 216                         ac00916045이 가장 매력적이었을 때....      6
# 217                              재미는 있었지만 흥미이상의 흥미는 없었다      8
# 218                                        스필버그 상상력의 극점      9
# 219                                          환타지 영화의 걸작      9
# 220                             3부작 중 가장 쳐진다. 그런데 걸작이다!      9
# 221                                 "원작도 영화도 명작, 명작이다."      9
# 222                                             골룸의 출세작      8
# 223                       어머어마하게 스펙타클한 완결판. 극장에서 보고 싶다.      8
# 224              mv00249901을 빼놓고선 환타ac01014715를 말할수 없다.      9
# 225               타티의 시선으로 풀어낸 mv00116599의 mv00501341사위     10
# 226                           뮤지컬을 싫어하는 나조차도 반해버린 멋진 영화      9
# 227                                      상실한 자아에 대한 탐구서      7
# 228                               완전 재밌고 캐릭터들이 너무 귀여웠다.      8
# 229                   "mv00106843, 그 속은 볼거리와 감동으로 가득하다"      8
# 230                         정말 재밌고 ac00394657진함이 넘쳤던 영화      9
# 231               컷 하ac01046800가 사랑스러운 로맨틱 영화의 기념비적 작품.     10
# 232                          보는내내 긴장감이 넘쳤던 최고의 범죄스릴러 영화      9
# 233                             '내가 바로 지브리다'의 저력을 확인하다.      9
# 234                           마음을 잔잔하게 울리는 만화 영화 이상의 영화     10
# 235                                이해는 하나 공감은 할 수 없는 영화      7
# 236                   mv00448192가 차려놓은 밥상에 배우는 숟갈만 놨을 뿐      8
# 237                                <트래픽>의 mv00448192 버젼      9
# 238                                  너무나 현실적이어서 더 끔찍한..      7
# 239                              손에 잡힐 듯한 mv00417310 공포      9
# 240              ac01105453 ac01370484를 좋아한다면 최고의 작품이다.      7
# 241                               'B급'은 B학점이라는 말이 아님을..      9
# 242                                  매력적인 청춘들의 수중발레 최고!      9
# 243                            정신분열에 시달리는 수학 천재학자의 이야기.      7
# 244                             환갑이 지나도 변치않는 mv00318466      7
# 245                             다시한번 상영하면 안될까.. 아까운 영화.      9
# 246                       ac00004255은 문자 그대로 '연기 귀신'이다.      7
# 247                          징그러울 정도로 연기잘하는 ac00020101.      8
# 248                         쉬리를 다른 버전으로 만든걸까. 애매모호한 정체성      5
# 249                             할머니'라는 단어에서부터 뿜어져나오는 정서      8
# 250                                ac00743596 정말 많이 컸다.      8
# 251                          액션만 따져도 이 영화는 엄청난 희소가치가 있다      8
# 252                                          오랜 기다림의 사랑      8
# 253                          원작의 공포를 살리지 못했지만 그럭저럭 볼 만함      6
# 254                             내레이션 활용이 돋보이는 따뜻한 성장드라마      8
# 255                           다르덴 형제식 리얼리즘이 빚어낸 기적의 순간들     10
# 256          mv00402415 브로디의 앙ac01475866 모습이 잊혀지지 않는 영화      9
# 257                                타격감이 살아있는 첩보 영화의 진면목      7
# 258                      상태가 마이 안 좋아. 눈도 별로인데 가슴도 못 채운다      4
# 259                                   "회자되고, 또 회자될것이다."     10
# 260                                  현실을 바탕으로 한 현실같은 영화      9
# 261                  mv00172710년 mv00296878 그들을 분노케 하라.      9
# 262                      오글오글.. 우연과 우연으로 점철된 간지러운 멜로...      6
# 263                         잔잔하고 mv00217576 동화와도 같은 이야기      8
# 264                               아슬아슬ac01200811르의 외줄타기      7
# 265                             사랑니... 아픔이 있는 아스라한 추억..      6
# 266                                     많은것을 생각하게 하는 영화      7
# 267                    "개인의 mv00259537, 그 이면의 모습을 잡아내다"      9
# 268                    ac00005977의 오버 액션 연기로 가득 채운 코메디.      6
# 269                     픽사스러운 캐릭터들. 이때부터 쭉 ac00204565다.      7
# 270                     픽사가 만든 mv00318625 영화도 역시 남다르구나.     10
# 271                                      외로운 영혼의 절절한 외침      8
# 272                여자를 그려내는 ac01047481 감독의 뛰어난 감정분위기 연출      9
# 273                                           최고의 반전 영화      9
# 274                       애니메이션인데도 그 안에서 환타지를 만들어내는 노련미      8
# 275                                 연기력 부족과 아동용 사춘기 로맨스      2
# 276                                 "권위와 폭력의 시대, 딱 그대로"      8
# 277                       잊고 있었던 공포영화의 계보를 이어주는 뛰어난 연출력      9
# 278                                  웰컴 투 더 헐리웃식 장르 영화.      6
# 279                               1편의 감성보다 2편의 짜임새의 판정승      9
# 280                  "1, 2편 합쳐서, mv00134716년대 최고의 오락영화"      9
# 281                       "권태 속의 불안, 잊히지 않을 아픈 잔상을 남기다"     10
# 282               다모덕에 폐인이 탄생했다.ac01011775의 변신은 여기서부터닷~      8
# 283                          "mv00393907 챕터는 정말이지, 감탄!"      7
# 284                                         0점이 있다면....      1
# 285                                    장난도 지나치면 도가 됩니다.      1
# 286                         미국식 코메디가 가득한 아이들 위주의 가족용 영화      4
# 287                                      아이디어 하나는 좋다...      7
# 288                  ac01431291의 출연만으로도 충분히 mv00069433.      8
# 289                      "카우프만과 공드리의 걸작, 멜로 영화의 새로운 발명"      9
# 290                       새로운 소재와 고전 소설의 조합이 이렇게 완벽할수가.      9
# 291                          남자에게 의존하는 여자의 시대에 종말을 고하다.      5
# 292          코메디 속에 녹아나는 미국의 mv00500086의 ac00223084 단면.      6
# 293                                 인간의 탐욕에 죽어가는 야생동물들.      8
# 294             화려ac00477430 무섭도록 mv00221251에 관한 심야 보고서     10
# 295                               "전형적인 로맨스, 무대가 윔블던일뿐"      6
# 296                            사랑하는 사람이 있다면 후회없이 사랑하세요.      9
# 297            억ac01381372 가족을 mv00457204 정신에 매치시키려는 노력      5
# 298                          또다시 보고 싶은 영화. 화합의 하모니는 멋있다      9
# 299                              쏘우라는 영화를 알린 놀라운 반전의 미학      8
# 300                              마지막을 위해 감내해야 하는 시간....      6
# 301                        영화와 현실이 너무도 달라 약간 아쉬움이 느껴졌다.      8
# 302                                  그저 편안히 보면 마음이 편해진다      8
# 303                  스토ac01378401다 mv00067255형 액션만 신경써라      6
# 304                  "각색의 방향을 잃자, ac00000043도 어쩔 수가 없다"      5
# 305                                종교적 동화의 서사. 시작은 무난했다      7
# 306                        조악하다. 그러나 폼이 빠진 진짜스런 액션이 숨쉰다      7
# 307                             지금 상황에따라 다르게 mv00282862      9
# 308                            리셋하기 힘든 인생. 폭력의 순환에 대하여.      8
# 309            ac00004897이 사랑을 가지고 ac01317645하게 테니스를 치다      9
# 310                        모성애로 끝까지 밀어붙이는 mv00217576 동화      7
# 311                              조금은 아쉬웠으나... 응원하고 싶네요!      7
# 312                     "'사랑할 수 있을까?"" 그 불안감이 나쁜것은 아니다"      8
# 313                                     아.. 별이 모자란다..ㅠㅜ     10
# 314                              메마른 감성을 적셔오는 한폭의 수채화!!      9
# 315                                        아스라했던 기억이...      8
# 316                                          속도와 액션에 올인     10
# 317                     장면을 덜어낼ac01448826 잊을수 없게 만드는 경지      9
# 318                            쏘우~역시 최고의 스릴을 보여준 놀라운 작품      8
# 319                        ac01242580다운 연출력이 돋보인 놀라운 영화      8
# 320          mv00300271를 통해 ac00407161이라는 배우를 다시보게 되었다.      8
# 321                                     역시 일본이라는 말밖에...      7
# 322             mv00392482은 아무나 하나? 이정도는 되어야 mv00392482      8
# 323                            엄청난 몽골 서사의 그 시작을 알리는 영화.      7
# 324      mv00062329로 포장한 죄와벌과 mv00365335의 오묘ac00887128합      9
# 325                         타임킬링용. 데이트할 때나 가볍게 보면 좋을 영화      6
# 326                              신나긴 한데 왜 신나는 진 모르겠다...      5
# 327                      한국에서 통하기 힘든 미국식 코메디. 허탈한 느낌 가득      5
# 328                      게이 로맨틱 코메디. 동성애물답게 센스있는 패션 감각.      6
# 329                             공포영화가 무섭지 않은 mv00298888      3
# 330                                      프랜시스 맥도낸드의 재발견      6
# 331                                   거룩한 척 하는 것이 꼴사납다.      2
# 332                               한국 역사의 근원의 길을 홀로 답사하다     10
# 333                                  겁나게 빠르다는 거 빼고는 평작.      6
# 334                                   반짝이는게 전부 보석은 아니다.      6
# 335                         치매에 대한 이해와 대처방법을 잘 알려준 감동영화     10
# 336                            배우들의 잔잔한 내면연기가 좋은 감성치유무비      6
# 337                                스키점프 장면만으로도 일단 합격이다.      8
# 338                                   2시간이 전혀 아깝지 않을 영화      9
# 339                            국내호러물로선 보기드믄 잔혹극을 펼쳐놓았다.      8
# 340                                     10년 만에 보내는 작별인사      8
# 341                                  우리 인생의 절반을 같이한 삼총사      9
# 342                                 대미를 장식했다는 말이 충분한 영화      8
# 343                            추억 ac00887128각의 이상적인 구두점      9
# 344                       최종편다운 볼거리와 분위기. 최종편답지 못한 싱거움.      7
# 345                            해리포터가 보내는 마지막인사로 부족함이 없다      9
# 346                        "소위 '스타'가 떠주니, 영화에 생기가 돌더라~"      7
# 347                              문제점은 직시하고 정확히 파악해야 한다.      6
# 348                          이 영화가 차라리 저예산의 쌈박한 영화였다면..      5
# 349                                 괴물은 해냈고 7광구는 하지못한 것      6
# 350                       기대를 갖고 즐기기에도 좋은 몇 안되는 중국액션영화.      7
# 351                          "불친절함, 모호함, 애매함, 그것이 인생이라"      9
# 352                   <mv00093961의 모든것 2>! 놀라운 이야기에 박수를      9
# 353                          "추격자의 아류, ac00488488의 원맨쇼"      6
# 354                          딱히 특별한 느낌이 없는 범작으로 기억되는 작품      8
# 355                       매력 120%충전 상태의 mv00243160 추리극.      7
# 356                        느릿하게 흘러가지만 가슴을 두드리는 무언가가 있다.      8
# 357                               역시 ac01233717은 미쳤어 ㅋㅋ      7
# 358                                         당당한 그의 첫발자국      7
# 359                              중년남자의 부서져가는 육체가 지닌 숭고함      9
# 360                                  굳이 만들었어야 했나 싶은 속편.      5
# 361                              가끔 과도함에 손이 오글오글해진다....      7
# 362                     "산악인들의 삶과 죽음, 도전정신을 다룬 산악영화.  "      8
# 363                     밑mv00254206 곡괭이로 한 번더 파고 내려간 느낌      8
# 364               "일본식 세상에서 mv00185524 mv00122338, 깔끔."      7
# 365                                        가슴을 후펴파는 진정성      8
# 415                                  ac01210297 출연작 중 갑      7
# 416                "mv00453865판과 헷갈려 낚였지만, 원작다운 힘이 있다."      7
# 417                                    식상할 수 있는 로맨틱코미디물      6
# 418                                     어쩜 우린 너무 불친절 해!      8
# 419                                  다큐.. 세상을 변화 시키는 열정      7
# 420               "레이싱장면에서 특히 폭발하는 mv00045760, 그것이 장점."      6
# 421                      좀비물을 가장한 사회비판적인 메시지가 담긴 묘한 영화.      6
# 422                       가볍게 웃으며 볼 수 있는 로맨틱코미디로서는 충실하다      7
# 423                             속성으로 볼 수 있는 그리스 신화이야기..      7
# 424                                 "정신차려, ac01015753!"      3
# 425                                      현실적인 산악 스릴러 영화      6
# 426                     조용한 감성. 빈공간을 ac01200883 마음 채워넣기      7
# 427                         피아노의 선율과 감동으로 가슴을 멍하게 만든 영화      9
# 428               연출이 부족ac00477430 실화가 주는 힘은 믿기 어려울 정도다      9
# 429                      난 이 영화의 고어씬의 질감만 인ac01266023다.      5
# 430                        ac01193161이 만들어낸 흥미로운 망상의 세계      7
# 431                              ac00906718 최고의 케이퍼 무비.     10
# 432                                  뻔한 웃음포인트마저 점점 싫어진다      3
# 433             ac01214095식 mv00207364는 얼굴이 아닌 시공간을 비튼다      9
# 434                              스릴러적 긴장감의 부족과 의미화의 가벼움      5
# 435                            감동적이며 따스함이 느껴졌던 매우 좋은 작품      9
# 436                                히어로 스타일을 빌려온 로맨틱 코메디      5
# 437                              늑대개 이후의 가장 괜찮은 썰매개 영화.      8
# 438                                       대체에너지 단체 홍보영화      4
# 439                           007마저 탐한 첩보액션의 ac01134229     10
# 440               <mv00090655>과 <mv00094141>의 21세기판 진화.      7
# 441                       멈추지 않는 야심유랑! ac00035248의 대발견!      8
# 442                              <도가니>보다 더 지독한 현실을 만나다.      9
# 443                          메세지에 집중하자. 행동의 변화를 부르는 영화.      9
# 444                            "보고서는 정말 독특한데, 뭔가가 부족해."      6
# 445                              사랑에 있어서 mv00076297의 의미      9
# 446                            지금의 ac01242580을 만들어 준 작품      7
# 447                                음악적 로드무비의 감수성.제2의 원스      7
# 448                                      어설픈각본과 어설픈 연출.      5
# 449                           "남녀노소, 전 세계를 사로잡은, 팬시영화?"      6
# 450                                          차갑고 뜨거운 걸작     10
# 451                       링위를 올라설때보다 링위를 내려올때는 확실히 성숙했다      9
# 452                        "배트맨이 아니라, 다크나이트. 그 묵직한 이름."     10
# 453                피할 수 없는 근원에의 물음ac00920758 진부한 성찰과 고뇌      7
# 454                    ac01299890를 다시볼수 없다는것이 매우 안타까웠다.      9
# 455                                     5점을 주려다 6점을 줬다.      6
# 456                         ac00001651의 절제된 연기가 돋보였던 영화      8
# 457                                   ac00000220에게 맞는 옷      8
# 458                        mv00147493을 엿보다 참다운 삶을 깨닫다..      7
# 459                "거스 반 산트, 톰 튀크베어, mv00197584 페인 Up!"      6
# 460                                   너무 너무 재밌고 흥미로운 영화      9
# 461                             그나마 3편보다 낫다는 데 위안을 삼는다;      6
# 462                                       원작을 무난하게 살리다.      6
# 463                                "상처를 어루만지는, 속내를 꺼내는"      8
# 464                   mv00083629 초특급 진화~! 다만 널 사랑하고 있어.     10
# 465                 "거침없이 전진하는 mv00134881, 게다가 영리하기까지."      9
# 466                         지금의 우리 현실.. ac00474781가 좋은가      9
# 467                                    정신못차릴 정도의 황홀한 연출      9
# 468                                       무거움 속에서도 담담함.      8
# 469    결혼에 관한 mv00315ac01158825를 mv00048640에서 로맨틱하게 풀다.     10
# 470          ac00212374 프랑스 요리를 소개하는 영리한 쥐 ac01436255팅~      7
# 471                           미국식 코메디의 전형. 그리고 한물간 스타들.      5
# 472                   평생 애 쓴 어머니와 세월과 함께 성장한 mv00416725      8
# 473                      "지루함없이 깔끔했고, 보편적인 재미를 가지고 있다."      7
# 474                             "1편이 별로였는데, 그보다 더 못하다니"      4
# 475                                  조작에 관한 차분하고 진중한 한방      8
# 476                                      체코판 mv00021436      8
# 477                         패러디 히어로물. 이 영화의 모범답안은 킥애스다.      3
# 478                아! 영화 mv00435712 없이 참 맑네요. 이런 영화 좋더라      8
# 479                              배우와 캐릭터가 딱 들어 맞는 엉뚱 영화      7
# 480                         "핀처가 영화를 찍는 장르로서, 새로운 방향성."      8
# 481                                 살고싶어.. 류핑궈의 나즈막한 탄식      7
# 482                          "여러 식재료를 섞어봤는데, 의외로 개운한 맛"      6
# 483                    화면을 캔버스 삼아 펼치는 자유로운 mv00370375..      8
# 484                            슬픔은 이겨내는 것이 아니라 견뎌내는 것이다      9
# 485                        음악과 함께 너무나 신나고 즐겁게 볼 수 있는 영화      9
# 486                               생각할 여운과 과거를 회상케 하는 애니      7
# 487                        "만남이 있으면, 헤어짐도 있는...날 울리는.."      9
# 488                                    역사상 가장 완벽한 끝마무리.     10
# 489                              그냥 그냥..ac00145360.. 그냥      4
# 490                                 나는 영화(라고 하고 싶지 않)다.      4
# 491                            밑도끝도 없는 엉성한 공포.분장만 볼만했다.      6
# 492                                             섞다만 물탄주      5
# 493                            10대 소년의 심리를 '영화'답게 표현해내다      7
# 494                                     이들의 한계는 어디까지인가.      9
# 495                            mv00147892의 고독을 느낄수있는 영화      9
# 496                       여러가지 건액션들의 장점을 잘 섞어빚은 스타일성 무비      7
# 497                                            갖출것만 갖췄다      6
# 498                                  보노가 다가오는 희열을 느껴봅시다      8
# 499                          "의미깊은 영화지만, 다소 밋밋하다는 단점.."      6
# 500                       "실패한 어머니의 '가정', 해결책으로써의 '예술'"      9
# 501                                부엌이 왜ac01271239 심심한가      4
# 502                         잔혹ac00477430 신비롭고 흥미로왔던 영화.      8
# 503                           끝의 시작. 최종편의 교두보치고 나쁘지 않다.      7
# 504                              그 똥 통 속에서도 파리들은 살아 숨쉰다      8
# 505                       코비니스부터 셀린느까지 다뤘다면 더 좋았을 텐뎅...      7
# 506                                사랑에 서툰 남자들이 보아야 할 영화      7
# 507                                     간만에 뒤통수 제대로 맞았네      5
# 508           SF mv00446488의 탈을 쓴 '팍스 mv00395173나' 선전물.      4
# 509                  블랙호크다운 + mv00502663 = 월드mv00442759      7
# 510                                  소통과 사랑을 같은 위치에서 보다      6
# 511                    mv00107434의 숨결을 고스란히 담아내긴 했지만...      7
# 512                       피아노 선율을 따라 흐르는 사랑을 느낄 수 있는 영화      8
# 513                                          음악만은 최고였다.      8
# 514                              공포보다는 즐거움을 강조하는 괴팍한 호러      8
# 515                               B무비를 이렇게 잘 만들기도 힘들텐데!      7
# 516                          현대인의 궁핍한 처지를 적나라하게 드러내는 풍경      9
# 517                                    "이성과 용기, 그들의 배신"      8
# 518                                   면접은 낚시 결국은 도박 얘기.      6
# 519                      "이 영화로, 만화가 아니라 애니임을 깨닫게 되었다!"     10
# 520                             사람들이 보고 가장 반성해야 할 러브스토리     10
# 521                             과연 픽사가 이 작품을 넘어설 수 있을까?      9
# 522                                           액션의 새로운 결      7
# 523             동화를 비트는 mv00205993 상상력이 바닥을 mv00244180.      5
# 524                               이율배반의 세상사에 던지는 코엔의 명답     10
# 525                                  mv00001962년 비쥬얼 쇼크      7
# 526                    화끈한 액션을 기대하지않고 가서 보면 mv00069433다      7
# 527                        한낱 시각효과에 머무르게 한다는 생각을 들게한 영화      6
# 528                        화려한 CG를 만난 것만으로도 충족감이 생기는 영화      7
# 529                            mv00158020의 감성으로 만든 오락영화      5
# 530                      "적절ac00477430, 심심한 mv00076489"      6
# 531                         (등급에 걸맞지않게) 동심을 자극하는 순수한 공포      7
# 532                     제작자 ac00001549 감독에게 아리랑치기 당한 기분      5
# 533                        본능과 ac00842164 싸움을 차근차근 풀어낸다      8
# 534                                        생각은 하지 말고 보자      3
# 535                                  특별한 활약없는 볼거리. 과유불급      6
# 536                        전반부는 지루했지만 후반부에 만회해서 다행이다...      7
# 537                                        너무 길었던 152분.      6
# 538                      그래도 안볼수는 없다는 게 ac01161235 최대단점      6
# 539                                             파괴 종결자.      6
# 540                   다시는 볼 수 없는 ac01187998의 마지막 모습....      8
# 541                           MJ는 이런 사람이였구나. 우린 왜 몰랐을까.      8
# 542                             세계 모든 분쟁 지역에 평화가 깃들길...      7
# 543                                     전쟁이 군인들에게 주는 폐해      7
# 544                             '폭주하는 기차'라는 안티 히어로의 대활약      8
# 545                                  애니메이션과 실사를 넘어서는 순간      9
# 546                          3D로 꼭 보기를 추천하는 손에 꼽는 애니메이션      9
# 547                               눈으로 확인하기 전까지 믿을 수 없다!      9
# 548                                   드림웍스의 픽사화는 성공이였다.      8
# 549                  "견딜 수 없는 고통. 아프고, 아프고, mv00165583"     10
# 550                              점점 세공되고 있는 정보서의 빛나는 성장      7
# 551                         케서방이 간만에 본인의 진면목을 유감없이 발휘하다      8
# 552                              ac00003466의 연기력에만 만족하자      5
# 553                                 가족의 행복을 위해 아버지는 죽었다      7
# 554                          "인도영화를 묻는다면, 이 영화를 추천하겠다!"     10
# 555                      ac01288974 휴머니즘과 감동을 느낄수 있는 영화      8
# 556                       타임킬링용 그 ac01130407 될 수는 없는 영화      6
# 557                     "공감가지는 않지만, 이해는 되는 남학생들의 이야기. "      7
# 558                      사람들의 마음을 치유해온 우리 가짜 진짜 의사 선생님.      8
# 559                                 사회문제로 둔갑한 진부한 사랑이야기      6
# 560                                   찌질해서 더 매력적인 수퍼히어로      7
# 561                             상상력도 이야기의 힘도 느껴지지 않는다..      5
# 562                                      생각보다 별로더라 에라이~      5
# 563                      가볍게 생각하고 볼 수 있는 산뜻한 mv00076489      7
# 564                    굉장히 미국적인 드라마. ac00477430 감동적이었다.      8
# 565                               감동은 있지만 그다지 오래가지 않는다.      8
# 566                               "영상미가 있는, 뜨거운 사랑의 여정"      7
# 567                         "mv00217576 체념, 희망도 품고 있다."      7
# 568                             mv0002ac011588257의 번외편?      6
# 569                       그 누구에게는 그것이 그토록 소중한 바램일진데....      6
# 570                             "원빈에 의한, 원빈 팬들을 위한 영화."      7
# 571                      "배우로서 원빈의 진화, 한국 액션 영화로서의 가능성"      7
# 572                            "연기력에는 박수를, 내용에는 비판을..."      7
# 573                          시대의 눈동자를 읽어야 인물들의 눈동자도 보인다      6
# 574                                  mv00102700의 득과실을 보      7
# 575                                     시대가 잉태한 음지의 이물감      7
# 576                               대만판 mv00237190을 보여주다.      6
# 577                             무협영화 속에 나타나는 중국의 문화패권주의      7
# 578                               "딱히 불만은 없는데, 만족도 없다."      5
# 579                         ac00442456기에 가슴에 뭍고 싶은 ....      8
# 580          "ac00325771, 시애틀, 쓸쓸함, 그리고 ac01145020의 욕심"      7
# 581                              ac00325771에 의해 완성되는 영화      8
# 582                                온 몸이 쫄깃쫄깃 mv00232456      7
# 583                       비슷한 소재의 후발주자로서 뛰어날 것이 없는 만듦새.      5
# 584                       "열심히 하는 모습은 좋은데, 지루하고 재미가 없네"      6
# 585                         정의라는 이름하에 자행되는 공권력의 무자비한 폭력      8
# 586                            평범ac00477430 매우 의미 있는 영화      7
# 587                                   말이 필요없다.. 걍 쵝오다!!     10
# 588                         "심리학적 육체훼손 필름, 스릴러의 기이한 경지"      9
# 589                                     나는 누군가 또 여긴 어딘가      8
# 590                               이 세상 모든 예술가들에게 바치는 헌사     10
# 591                               "모호한 도덕성, 아슬아슬한 캐릭터들"      7
# 592                                 과학이 운명지어버린 아이들의 이야기      6
# 593                                  사람이 어떻게 변하는지 잘 보게나      7
# 594                                성인 남성에겐 버거울 수 밖에 없는가      6
# 595                 mv00140761만으로도 이 영화는 충분히 mv00165583      7
# 596                              사람은 사람과 있을 때 사람다울 수 있다      8
# 597                                     잘 만들었다. 스토리만 빼고      7
# 598            한층 ac00296665 액션과 폭력이 메ac01450532 못한 공허함      5
# 599                         각 재료들이 잘 버무려진 맛깔나는 비빔밥같은 영화      7
# 600                         이들이 한 앵글로 볼수 있다는 것만으로도 큰 축복      9
# 601                              교집합 없는 캐릭터의 합집합은 더욱 크다     10
# 602                       "'실패'를 의도한 영화였다면, 굉장히 성공한 영화"      1
# 603                                    극한의 남극에서도 먹고 싶다.      8
# 604               눈부신 ac01192492때문에 감정의 떨림을 잡아내긴 쉽지 않다.      8
# 605                     mv00221200는 안보이고 콘티만 mv00282862      5
# 606                                        멋을 부리다 맛을 잃다      6
# 607                                  그래도 요리는 손맛이고 정성이다.      5
# 608                                       합창만큼은 정말 감동적!      7
# 609                     '이mv00339967'의 외침에서 발생하는 뼈있는 웃음      7
# 610                                제목만큼의 강렬함이 없어서 아쉬운..      6
# 611                      "완벽하진 않지만, 매력적이고 깊이 있는 심리 첩보물"      8
# 612                                         환타지가 빠진 환타지      4
# 613                       지브리 특유의 따뜻한 색감과 참신한 소재는 여전하다.      7
# 614                      mv00076489에서 이 이상을 바란다면 그것은 욕심      8
# 615                      '짐승'이란 제목이 새겨지던 오프닝 크레딧만 강렬하다.      2
# 616                          발ac01362660 ! 이제 세계로 나갈 차례      7
# 617                           현실에서 떠날 수 있음은 영화의 매력이 아닐까      9
# 618                              발ac01362660라서 가능한 어떤 것      7
# 619                      무거운 주제와 가벼운 이야기 사이를 자유롭게 넘나든다.      8
# 620                     "ac00176365 영화, 그 이상 그 이하도 아닌."      7
# 621                        무거운 주제를 웃음으로 풀어낸 웰 메이드 힌디 영화      9
# 622                           "코믹영화, 너무  따지면서 보지는 맙시다!"      9
# 623                         팬더곰의 정체성 찾기. 나는 mv00374080.      8
# 624                                   "진화한 영상, 퇴화한 이야기"      7
# 625                        노인을 위한 나라는 없어도 노인을 위한 사랑은 있다      8
# 626                           따스하면서도 가슴한켠이 울컥해지는 영화였어요~      8
# 627                                배우들의 연기력과 연출력이 어우러졌다      9
# 628                                   야구를 너무 사랑한 나머지 그만      6
# 629                    "액션 홈즈는 식상해, 추리와 탐구의 모습을 보여주길. "      5
# 630                        커진스케일과 자가반복의 그 중간쯤에서 재미를 찾다.      7
# 631                             그렇게 어린 사슴은 스스로 맹수가 되었다.      8
# 632                                  사소한 문제라고 생각하다간 차인다      9
# 633                              음지에서 양ac01381372 한 걸음!      8
# 634                                  mv00378109마저 섬뜩하다.      8
# 635                                       전설로 남을뻔 했는데..      7
# 636                                 9천원에 만끽하는 시청각적 우주탐방      8
# 637                  피와 땀 그리고 눈물로 빚어낸 mv00031762의 한판 승부      8
# 638                         mv00164173에 관한 정신분석학개론 겉핥기.      6
# 639                                    ac00675373의 현실인식      8
# 640                        지구인 다 된 외계인. 지구에서 살만큼 살았다고..      8
# 641                                      소년은 아픔속에 성장했다.      9
# 642                              한국 3D애니의 진화를 자랑스레 보여준.      7
# 643                                         그래도 삶은 지속된다      7
# 644                    "동트기전 새벽이 어둡고, 봄이 오기전 겨울이 매서운 법"      9
# 645                      지독히도 씁쓸하게 삶을 성찰한다. 너무도 끔찍한 걸작.      9
# 646                          '단막극'이라는 표현이 자꾸 떠오르게 만든 영화      6
# 647                                   '은퇴≠모든 것으로부터의 퇴갤'      9
# 648                                민족주의의 그늘에서 벗어나는 첫 걸음      7
# 649                                        동족상잔 따위는 잊어라      8
# 650            좋은 mv00221200가 좋은 감독과 mv00102760를 만나면...      9
# 651                  깊이와 mv00339388를 겸비한 탁월한 반전(反戰)영화!!      9
# 652                           "JSA프리퀄, 공동전쟁구역 고.지.전..."      9
# 653                                         복제품의 뛰어난 효용      9
# 654                       진짜 같은 가짜 부부의 ac01013755 사랑 담론      7
# 655                     이런 망가지는 ac00000598가 왠지 더 매력적이다.      7
# 656                                   밟으면 깨질것같은 얇은 얼음벽.      8
# 657                         원작의 감동보다는 주연여배우의 연기가 돋보인 작품      7
# 658                "ac00005770만의 색깔, 그녀라서 만들 수 있었던 영화."      8
# 659                     "진실을 직시하는 용기에 대하여, 이것은 실패가 아니다"      7
# 660                         음모를 다룬 영화로서는 평균점. 후반부가 아쉽다.      7
# 661                                       얄팍한 상술이 빚은 참극      4
# 662                "용기에 관한, 사랑스러운 파리의 속 낭만 mv00455617."      8
# 663                           "미국의 거장, 예술의 도시 파리를 동경하다"      9
# 664                        감독이 ac00007024이라는 것을 기억해야한다.      8
# 665                             능력치의 절반이 사라진 ac00007024      6
# 666                                         시리즈 컨셉을 바꾸다      7
# 667                            무념무상의 정신으로 모든 걸 때려 부수는구나      7
# 668                               좋은 비행기에 불량품 날개를 달아준 셈      7
# 669                           모든 게 익숙하다. 그럼에도 마음은 움직인다.      7
# 670                    음 mv00142408의 기생ac00768910이군! ㅋㅋ      7
# 671                        가볍게 웃으며 즐길 수 있는 mv00076489^^      7
# 672                      이정도라면 시리즈의 명예로운 귀환이라 할만함. 대만족.      8
# 673                            나쁘지않은 전개 뻔하지않는 전개가 새로웠다.      7
# 674                      거대자본이 만든 가장 소박하고 아련ac00441493간      9
# 675                             ac00003058의 진심과 애정의 동화!      9
# 676                   여전히 죽지 않았구나. 오프닝은 압권. mv00382117!      9
# 677                                  실화보다 영화가 졸린 희한한 경험      4
# 678                               음악은 좋았다. 인생은 한 번 길...      6
# 679                                   놀랄정도로 친근하게 다가온 영화      8
# 680                              파괴력 부족한 인물이 주인공이라는 아쉬움      5
# 681                         "귀신보다 무서운 인간, 그것만은 잘 표현했다."      6
# 682                                 곡사의 취향과 충무로 입맛의 절충점      6
# 683                    ac01192492와 사운드는 확실히 좋은 공포 자극 영화      6
# 684                     "경계를 둘러싼 상처와 슬픔, 냉혹한 침묵으로 폭발하다"      9
# 685                        정의를 내리게 하는 차이가 있는걸 실감케 하는 영화      5
# 686                                           그들의 시선으로.      8
# 687                              "깊어진 스토리, 그러나 줄어든 상상력"      6
# 688                                          1 >> 3 > 2      6
# 689                      특유의 mv00266473함과 긴장감이 모두 사라졌다.      5
# 690                            ac00004525가 오락영화를 만들면...      7
# 691                         아름답지 않은 삶을 통한 역설이 다소 힘에 부친다      7
# 692                 또 한번 'mv00406612 바르뎀'의 존재를 확인하게된 영화      8
# 693                                  스텝들의 노고에는 박수쳐주고 싶다      6
# 694                       조금 억지스런 설정이 눈에 띄는 조금은 평범한 영화~      7
# 695                            (어느정도 양보만 한다면)최적화 된 여름영화      7
# 696                               "미완의도전, 장점과 한계가 확실하다"      8
# 697                                         주먹보다 무서운 소외      9
# 698                                   10대는 파수꾼일 수 밖에 없다      7
# 699                           지켜주지 못한 게 아니라 지켜주지 않은 파수꾼      8
# 700                 남자들의 청소년기 우정을 뒤늦은 파수꾼으로서 mv00324601      8
# 9789                       영화관에서 대형스크린으로 다시 보고싶은 영화 0순위     10
# 9790                                   참전을 부추기는 독소같은 영화      1
# 9791                                               good      2
# 9792               이 영화에 수식어를 붙이겠다고...   bullmv00431499     10
# 9793                                   내 생에 최고의 영화...ㅋㅋ     10
# 9794                                  그저 그런 영웅물에 가까운...      7
# 9795                              세월이 흐른뒤 다시봐도 명작. 최고다.     10
# 9796                                  여러번 봐도 질리지 않는 영화.     10
# 9797                         전형적인걸 알면서도 멋진 mv00002848장면      8
# 9798                                         OST가 너무 좋다     10
# 9799                             영화는 재미없지만; 영화음악 너무 좋다.      8
# 9800                                파일럿에 대한 환상을 심어주는 영화     10
# 9801                      비행 파일럿 영화중 이보다 잘 만든 작품이 있을까 ?      8
# 9802                        톰 형님 이땐 또 ac01192492가 틀리네~ㅋ      8
# 9803                       그 당시 최신기종인 F-14을 감상할수있는 보너스.      9
# 9804                   감동적이다.^^근데 ac01161235 12세이용가아닌가?     10
# 9805                                    탑건2가 나오길 기다리며^^     10
# 9806                                                최고.     10
# 9807                      전형적인 헐리웃 mv00446488..너무 교과서적인      7
# 9808                         ac01331368를 세계최고 스타로 만든 영화     10
# 9809                                            질주하는 청춘      8
# 9810                             제리 브룩 하이머의 mv00230755.     10
# 9811                           OST명작...내용은 지루하게 봤던 기억..      7
# 9812                      미국우월주의등의 말로 재미없다는 사람 이해가 안감..     10
# 9813                                이거 재밌다는 사람이 제일 이해안감      2
# 9814                                               GOOD      9
# 9815                                                최고지     10
# 9816                     mv00041958 나에게 꿈을 주웠던 영화......     10
# 9817                                이것때문에 조종장교 지원했었쥐...     10
# 9818                  진짜 스케일부터가 틀리네 맥ac00782011신인때도 나오고      9
# 9819                                오드리 햅번 정말정말 아름답습니다.     10
# 9820                                  시대가 흘러도 언제 봐도 재밌다     10
# 9821                                   말이 필요없는 명작. 명물허전     10
# 9822                      우울했는데 참 맑아지네요 너무 기분 좋은 영화입니다♡     10
# 9823                                       시대를 초월하는 명작.     10
# 9824                           우아하고 기품 있는 고전 mv00076489      7
# 9825                             로마는 이 영화를 보고나서 갔었어야 했다     10
# 9826                                  오옷 ac00000319 이쁘다     10
# 9827                                     이런걸 명화라고 부르는구나     10
# 9828                                이런 영화를 바로 명작이라고 한다.      9
# 9829                 ac01279194의 미소를 나는 영원히 잊지 못할 것 같다.     10
# 9830                     화려하지도 세련되지도 않지만 충분히 mv00165583      9
# 9831                              mv00217576 영화 ~ ~ ~ ~     10
# 9832                                     "로마에 가고 싶다,,,"     10
# 9833                    말이필요없는 명작ac01279194 mv00307324!     10
# 9834                             내용은 유치한데 오드리 햅번 진짜 이쁘다      9
# 9835                우와와와와 괜히 명장이고 ac01052320가 아는 영화가아니다     10
# 9836                                    명작이 왜 명작인지 알겠어요     10
# 9837                    정말 ac00423565게 흑백인데도 mv00407077      9
# 9838                         "아~~~~나의 영원한 ac00002914,,"     10
# 9839                                      내 최초이자 최고의 영화     10
# 9840                                          gpgpgp헤헤헤     10
# 9841                   심연을 어루만져주는 감동.. ac01297807 너무 멋짐     10
# 9842                                          명작중의  명작!     10
# 9843                                   흑백인데도 오드리햅번은 ...     10
# 9844                             가장 로맨틱하면서도 가슴이 맑아지는 영화     10
# 9845                              오드리 햅번을 위한 mv00418906      7
# 9846                              귀엽고 풋풋하고 뭉클한..낭만이 넘친다     10
# 9847                                       기대에는 못미쳤던 영화      8
# 9848                                      세월이 흘러도 변치않는.     10
# 9849                  아 왜 내가 ac01161235를 흑백이라고 안보고 있었을까     10
# 9850                                  명작이다 .. 아 .......     10
# 9851                                      그냥.. 이것이 영화다.     10
# 9852                            이 영화를 왜 지금에서야 봤을까..최고..     10
# 9853                          지금 KBS1에서 더빙판으로 하고 있음. 강추     10
# 9854                         볼때마다 나를 설레임 넘치는 소녀로 만들어준다.     10
# 9855                                       영화에 기품이 있어..      8
# 9856                       고전만의 mv00217576 여운.. 부디 영원하길     10
# 9857                              나름 괜찮았다. 엔딩이 좀 아쉬움...      7
# 9858                                     다시는 안나올 세기의 명작     10
# 9859                                 오드리오드리오드리 ㅠㅠㅠㅠㅠㅠㅠㅠ     10
# 9860                                         깔끔한 느낌의 영화      9
# 9861                                             추억의 명작      7
# 9862                                                헵번♥     10
# 9863                                      mv00217576 영화     10
# 9864                       나도 드디어 봤다! 정말 재밌었음. 최고~! ㅋㅋㅋ     10
# 9865                        꿈의 mv00091984 끝에서 다가온 현실...     10
# 9866                          "세상에서 mv00185524 결말 ,,,,"     10
# 9867                             영화가 꿈꿀 수 있는 최고의 로맨틱스토리     10
# 9868                     아무 생각없이 영화에 집중하며 행복하게 볼 수 있었다.      9
# 9869                         "Rome. By all means, Rome"     10
# 9870               "영화는 흑백ac00920758, 로마의 사랑은 총천연색이었다."     10
# 9871                                   보고만있어도 웃음이 나오는영화     10
# 9872                             별점이 10개밖에 없다는것이 아쉬울뿐..     10
# 9873                                         말이 필요없는 영화     10
# 9874                             너무나 아름답고 사랑스런 오드리 햅번..      8
# 9875                              오드리햅번이 머리자르는순간...감탄연발     10
# 9876                            쳐울었다. 공주님 눈만 봐도 눈물이 난다.     10
# 9877                                 역사에 길이 남을 영화일 겁니다.     10
# 9878                                걸작... mv00217576 영화     10
# 9879                                             그닥재미없다      6
# 9880                                      오드리햅번이 남긴 옛명작     10
# 9881                           왠지 가슴한편이 뭉클해지는 영화 !! ^_^     10
# 9882                     이게 뭐냐.. 재미없는 흑백 영화 보느라 죽는줄 알았다      1
# 9883                                        그녀는 역시 최고!!     10
# 9884                         명작이라 불리우고 기억에 계속 남는 이유가 있다     10
# 9885                                   정말 재미도 없고 감동도 없다      1
# 9886                                           명작이죠 ...     10
# 9887                                    10분 보고 꺼버렸다 ㅡㅡ;      1
# 9888                            사랑할 수 밖에 없는 ac00000319!     10
# 9889                                                그닥;      1
# 9890                                        꿈mv00448015     10
# 9891                                       말이필요없는 최고의영화     10
# 9892                         기대보다 재밌었던 영화. 오드립은 정말 이쁘다.      8
# 9893                           ac01355233화 교수님 만세~!~!~!     10
# 9894                          로마에서 그녀의 모든것을 따라했던 고전적 영화      9
# 9950                            정말 잊혀지지 않는 영화가 될것 같다...     10
# 9951                      봐도봐도 너무 감동깊은 영화에요 영화음악도 좋구요^^     10
# 9952                    "멜로 영화중 최고. 배우, 연기, 배경 모두 별 5개"     10
# 9953                                    최고의 mv00076489.     10
# 9954                                       정말 정말 최고입니다!     10
# 9955                                 거짓말 안 하고 20번은 본 영화     10
# 9956                        영화 보면서 가장 많이 울었다.너무 많이 울었다.     10
# 9957                   ac01161235가 와닿지않는 감성의소유자는 불쌍한겁니다     10
# 9958                                     재미없을줄 알았는데 명작.     10
# 9959                         내 인생 명작 영화 아무리봐도 질리지가 않는다.     10
# 9960                      아무리 시간이 흐른다 한 들 이것보다 아름다울수 없어     10
# 9961                             10점. 더 이상 자세한 설명은 생략한다     10
# 9962                                 50번은 넘게본 말이 필요없는영화     10
# 9963                                    재밌게 본 영화입니다....     10
# 9964                      보고 또 봐도 ac01165234 최고의 뮤지컬 영화     10
# 9965                             랄프 사기꾼임 이런 남자랑 결혼하면 안됨      1
# 9966                                감명깊은 영화. 노래가 인상적이네요      9
# 9967                        어쩜 영화를 이렇게 뽑아낼수 있지? 할말이 없다.     10
# 9968                           몇번을 봐도 좋네요. 마음에 남는 영화에요.     10
# 9969                                    멘탈을 클린하게 만드는 추억     10
# 9970                                   이건 말이 필요없는 명작입니다     10
# 9971                 어떤 영화가 이보다 좋을수있을까~  mv00256903영화 ~     10
# 9972                                    다시봐도 재미있네요  ㅠ♡♡     10
# 9973                        진짜진짜명작중명작임..!!몇번을봐도질리지않는다ㅜㅜ     10
# 9974                    "재개봉 시사회로 봤는데 감동과 재미, 음악이 좋네요."     10
# 9975                                   mv00258037 최고!!!     10
# 9976                                      레전드 오브 레전드...     10
# 9977               좀  지루할수도 있지만 뮤지컬 드라마 영화의 ac00126568.      8
# 9978                              어릴적부터 지금까지 너무 사랑하는 영화     10
# 9979                                    보고 또 봐도 감탄만 나온다     10
# 9980                                      귯구ㅛ굿굿굿구수구수구수숫     10
# 9981                                      그레틀 카와이이~~ ~~      9
# 9982                                      명작만이 고전으로 남는다     10
# 9983                                     진짜 너무너무 감동적임~~     10
# 9984                         몇번을 보고 또 봐도 mv00217576 영화.     10
# 9985                         언제봐도 명작이다 몇번을 보고 또 봐도 명작이다     10
# 9986                                   언제 봐도 행복한 영화....     10
# 9987                                    음악도 정말 좋고 명작이지.     10
# 9988                           어려서보나 나이들어서 보나 몇번을 봐도 감동     10
# 9989                              ac01161235를보면 기분이좋아진다     10
# 9990                                      그냥 너무 좋네요 좋아요     10
# 9991                                     재개봉을17년마다 했네ㅋㅋ     10
# 9992                        ac00460096송 은19000번을봐도  굿이다     10
# 9993                       내 첫 인생 영화라고 자신있게 말할 수 있는 영화.     10
# 9994                                       어떤 미친놈이 1점줬냐     10
# 9995                      사운드어브 뮤직 ....그 자체로 10점만점에 10점     10
# 9996                                정말mv00217576영화 인생영화     10
# 9997                                  감동적이고  대령님이 멋있어요.     10
# 9998                              제가 가장 사랑하는 최고의 영화입니다.     10
# 9999                                       말이 필요없는 명작..     10

# %%
import translation

# %%
from translation import google

# %%
import re
re_score = re.compile("[1-9]?[0-9]점")

# %%
re_score.findall("10점 주기엔 에바여서 9점 줌")
# Out:
# ['10점', '9점']

# %%
from feature_extractors import ScoreExpressionExtractor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-97-2edc3ad3b920> in <module>()
# ----> 1 from feature_extractors import ScoreExpressionExtractor
#
# ImportError: cannot import name 'ScoreExpressionExtractor'

# %%
class FastTextVectorizer:
    """A dictionary that maps a word to FastText embedding."""

    def __init__(self, tokenizer, config):
        self.tokenizer = Twitter()
        self.vocabulary_size = config.vocabulary_size
        self.embedding_size = 256
        self.PAD_TOKEN = '<PAD>'
        self.UNK_TOKEN = '<UNK>'
        self.fasttext = None

    def build_dictionary(self, data):

        self.vocab_words, self.word2idx, self.idx2word = self._build_vocabulary(data)
        self.embedding = self.load_vectors()
        print(self.embedding.shape)

    def indexer(self, word):
        try:
            return self.word2idx[word]
        except:
            return self.word2idx['<UNK>']

    def _build_vocabulary(self, data):
        reviews = [review for review, label in data]
        tokenized_reviews = [self.tokenizer.pos(review, norm=True) for review in reviews]
        
        tokens = [[token for token, pos in tokenized_list] for tokenized_list in tokenized_reviews]
        tags = [[pos for token, pos in tokenized_list] for tokenized_list in tokenized_reviews]

        self.fasttext = FastText(sentences=[' '.join(review) for review in tokens],
                                 size=self.embedding_size,
                                 max_vocab_size=self.vocabulary_size-2)

        vocab_words = self.fasttext.wv.vocab
        word2idx = {word:idx for idx, word in enumerate(vocab_words)}
        word2idx['<UNK>'] = len(vocab_words)
        word2idx['<PAD>'] = len(vocab_words)+1
        
        idx2word = {idx:word for idx, word in enumerate(vocab_words)}
        idx2word[len(vocab_words)] = '<UNK>'
        idx2word[len(vocab_words)+1] = '<PAD>'
        
        return vocab_words, word2idx, idx2word

    def load_vectors(self):
        word_vectors = []
        for i in range(self.vocabulary_size):
            if i in self.idx2word:
                word = self.idx2word[i]
                if word in ['<UNK>', '<PAD>']:
                    vector = np.zeros(self.embedding_size)
                else : vector = self.fasttext.wv[word]
                word_vectors.append(vector)
            else:
                word_vectors.append(np.zeros(self.embedding_size))
        embedding = np.stack(word_vectors)
        return embedding

    def state_dict(self):
        state = {'idx2word': self.idx2word,
                 'word2idx': self.word2idx,
                 'vocab_words': self.vocab_words,
                 'embedding': self.embedding.tolist()}
        return state

    def load_state_dict(self, state_dict):
        self.idx2word = state_dict['idx2word']
        self.word2idx = state_dict['word2idx']
        self.vocab_words = state_dict['vocab_words']
        self.embedding = np.array(state_dict['embedding'])

# %%
class AbnormalWordExtractor:
    """
    되게 유의미할 것 같은 단어들 one-hot encoding
    """
    def __init__(self):
        self.n = None
        pass
    def fit(self, data):
        pass
    def extract_feature(self, raw_text, tokenized_text):
        abnormal_words_list = ['다세포', '형래', '우뢰매']
        
        self.n = len(abnormal_words_list)
        values = [0] * self.n
        
        for i, word in enumerate(abnormal_words_list):
            if word in raw_text: values[i]=1
        
        return tuple(values)

# %%
class ScoreExpressionExtractor:
    """
    Extracts score expressions
    """
    def __init__(self):
        self.re_score = re.compile("[1-9]?[0-9]점")
        self.re_star = re.compile("별 ?[0-9]?[0-9반] ?개")
        self.n = 1
        
    def fit(self, data):
        pass
    
    def extract_feature(self, raw_text, tokenized_text):
        """
        Returns:
            ??점을 말할 경우 그 값을 반환. 여러 개일 경우 마지막 값을 반환
        """
        values = [0]*10
        scores = self.re_score.findall(raw_text)
        stars = self.re_star.findall(raw_text)
        if stars:
            values[stars[-1]]=1
        elif scores:
            values[scores[-1]]=1
        return tuple(values)

# %%
from konlpy.tag import Twitter
twitter = Twitter()

# %%
class SleepnessExtractor:
    """
    Extracts 졸리다, 자다 expressions
    """
    def __init__(self):
        self.twitter = Twitter()
        self.n = 1
    
    def fit(self, data):
        pass
    
    def extract_feature(self, raw_text, tokenized_text):
        """
        Returns:
            졸리다라는 표현과 유사한 표현이 있는지 여부를 반환
        """
        sleepy = 0
        sleep_expressions = ['졸리다', '졸다', '자다', '자다']
        stem_tokens = self.twitter.pos(raw_text, norm=True, stem=True)
        for token, pos in stem_tokens:
            if token in sleep_expressions:
                sleepy=1
        return sleepy,

# %%
# normalizer
def delete_quote(raw_text):
    raw_text = raw_text.replace("'",'').replace('"','')
    if raw_text.find("10자")>-1:
        raw_text = raw_text[:raw_text.find("10자")]
    return raw_text

# %%
def sibalizer(raw_text):
    r = re.compile('씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}발|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}팔|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}빨|\
씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}벌|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}바|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}뻘|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}펄|\
시[ㄱ-ㅎㅏ-ㅣ0-9]{,3}바|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}파|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}빠|시[ㄱ-ㅎㅏ-ㅣ0-9]{,3}빠|\
시[ㄱ-ㅎㅏ-ㅣ0-9]{,3}파|시[ㄱ-ㅎㅏ-ㅣ0-9]{,3}발|신[ㄱ-ㅎㅏ-ㅣ0-9]{,3}발|씨[ㄱ-ㅎㅏ-ㅣ0-9]{,3}방|\
ㅅ[ㄱ-ㅎㅏ-ㅣ0-9]{,3}ㅂ|ㅆ[ㄱ-ㅎㅏ-ㅣ0-9]{,3}발|ㅅ[ㄱ-ㅎㅏ-ㅣ0-9]{,3}발|ㅆ[ㄱ-ㅎㅏ-ㅣ0-9]{,3}팔')
    for sibal in r.findall(raw_text):
        raw_text = raw_text.replace(sibal,"시발")
    return raw_text

# %%
--model=VDCNN_feat --tokenizer=JamoMaskedTokenizer --dictionary=RandomDictionary --features=BasicFeaturesExtractor_ImportantWordFeaturesExtractor_MovieActorFeaturesExtractor --epochs=100 --sort_dataset --lr_schedule --learning_rate=0.003 --min_length=64 --max_length=100 --embedding_size=16
